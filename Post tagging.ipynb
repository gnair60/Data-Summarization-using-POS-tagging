# %%
import bs4 as bs   #beautiful soup , useful Python utility for web scraping

# %%
import urllib.request    # parse XML and HTML

# %%
import re     #for regular expressions

# %%
import nltk #for nlp processing

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Gautam
# [nltk_data]     Nair\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Gautam
# [nltk_data]     Nair\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to C:\Users\Gautam
# [nltk_data]     Nair\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
scraped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Cricket_ball')     #accessing/scraping wiki data

# %%
article = scraped_data.read()    #reading the data byte-by-byte

# %%
print(article)
# Out:
# b'\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Cricket ball - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpMqyApAAEEAAHEoB2UAAABU","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Cricket_ball","wgTitle":"Cricket ball","wgCurRevisionId":948817494,"wgRevisionId":948817494,"wgArticleId":465529,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Use dmy dates from February 2013","Commons category link is on Wikidata","Balls","Cricket equipment"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Cricket_ball","wgRelevantArticleId":465529,"wgIsProbablyEditable":!0,\n"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1139973","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","jquery.makeCollapsible.styles":"ready","mediawiki.toc.styles":"ready","skins.vector.styles.legacy":"ready","wikibase.client.init":"ready",\n"ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","skins.vector.js","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.35.0-wmf.27"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/ ...

# %%
parsed_article = bs.BeautifulSoup(article,'lxml')      #to parse the data

# %%
paragraphs = parsed_article.find_all('p')     #text enclosed within <p> tag is retrieved

# %%
article_text = ""     #to combine the paragraphs

# %%
for p in paragraphs:  
    article_text += p.text

# %%
#Pre-processing
#Removing square brackets and extra spaces
article_text = re.sub(r'\[[0-9]*\]', ' ', article_text)  
article_text = re.sub(r'\s+', ' ', article_text)

# %%
print(article_text)
# Out:
#  A cricket ball is a hard, solid ball used to play cricket. A cricket ball consists of a cork core wound with string then a leather cover stitched on, and manufacture is regulated by cricket law at first-class level. The trajectory of a cricket ball when bowled, through movement in the air, and off the ground, is influenced by the action of the bowler and the condition of the ball and the pitch, while working on the cricket ball to obtain optimum condition is a key role of the fielding side. The principal method through which the batsman scores runs is by hitting the ball, with the bat, into a position where it would be safe to take a run, or by directing the ball through or over the boundary. Cricket balls are harder and heavier than baseballs. In day Test cricket, professional domestic games that spread over a multitude of days, and almost the entirety of amateur cricket, the traditional red cricket ball is normally used. In many one day cricket matches, a white ball is used instead in order to remain visible under floodlights, and since 2010, pink has been introduced to contrast with players' white clothing and for improved night visibility during day/night Test matches. Training balls of white, red and pink are also common, and tennis balls and other similar-sized balls can be used for training or informal cricket matches. During cricket matches, the quality of the ball changes to a point where it is no longer usable, and during this decline its properties alter and thus can influence the match. Altering the state of the cricket ball outside the permitted manners designated in the rules of cricket is prohibited during a match, and so-called "ball tampering" has resulted in numerous controversies. Injuries and fatalities have been caused by cricket balls during matches. The hazards posed by cricket balls were a key motivator for the introduction of protective equipment. British Standard BS 5993 specifies the construction details, dimensions, quality and performance of cricket balls. A cricket ball is made with a core of cork, which is layered with tightly wound string, and covered by a leather case with a slightly raised sewn seam. In a top-quality ball suitable for the highest levels of competition, the covering is constructed of four pieces of leather shaped similar to the peel of a quartered orange, but one hemisphere is rotated by 90 degrees with respect to the other. The "equator" of the ball is stitched with string to form the ball's prominent seam, with six rows of stitches. The remaining two joins between the leather pieces are stitched internally forming the quarter seam. Lower-quality balls with a two-piece covering are also popular for practice and lower-level competition due to their lower cost. The nature of the cricket ball slightly varies with its manufacturer. White Kookaburra balls are used in one-day and Twenty20 international matches, while red Kookaburras are used in test matches played in most of the ten test-playing nations, except for the West Indies and England, who use Dukes, and India, who use SG balls. Cricket balls are traditionally red, and red balls are used in Test cricket and First-class cricket but proposals to introduce other colours date back at least as early as 1937. White balls were introduced when one-day matches began being played at night under floodlights, as they are more visible at night; all professional one-day matches are now played with white balls, even when they are not played at night. The white balls have been found to behave differently from the red balls: most notably, they swing a lot more during the first half of an innings than the red balls, and they deteriorate more quickly. Manufacturers claim that white and red balls are manufactured using the same methods and materials, other than the dyeing of the leather. Another problem associated with white cricket balls used in One Day Internationals is that they quickly become dirty or dull in colour, which makes it more di ...

# %%
#Removing special characters and digits
formatted_article_text = re.sub('[^a-zA-Z]', ' ', article_text )  
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)

# %%
print(formatted_article_text)
# Out:
#  A cricket ball is a hard solid ball used to play cricket A cricket ball consists of a cork core wound with string then a leather cover stitched on and manufacture is regulated by cricket law at first class level The trajectory of a cricket ball when bowled through movement in the air and off the ground is influenced by the action of the bowler and the condition of the ball and the pitch while working on the cricket ball to obtain optimum condition is a key role of the fielding side The principal method through which the batsman scores runs is by hitting the ball with the bat into a position where it would be safe to take a run or by directing the ball through or over the boundary Cricket balls are harder and heavier than baseballs In day Test cricket professional domestic games that spread over a multitude of days and almost the entirety of amateur cricket the traditional red cricket ball is normally used In many one day cricket matches a white ball is used instead in order to remain visible under floodlights and since pink has been introduced to contrast with players white clothing and for improved night visibility during day night Test matches Training balls of white red and pink are also common and tennis balls and other similar sized balls can be used for training or informal cricket matches During cricket matches the quality of the ball changes to a point where it is no longer usable and during this decline its properties alter and thus can influence the match Altering the state of the cricket ball outside the permitted manners designated in the rules of cricket is prohibited during a match and so called ball tampering has resulted in numerous controversies Injuries and fatalities have been caused by cricket balls during matches The hazards posed by cricket balls were a key motivator for the introduction of protective equipment British Standard BS specifies the construction details dimensions quality and performance of cricket balls A cricket ball is made with a core of cork which is layered with tightly wound string and covered by a leather case with a slightly raised sewn seam In a top quality ball suitable for the highest levels of competition the covering is constructed of four pieces of leather shaped similar to the peel of a quartered orange but one hemisphere is rotated by degrees with respect to the other The equator of the ball is stitched with string to form the ball s prominent seam with six rows of stitches The remaining two joins between the leather pieces are stitched internally forming the quarter seam Lower quality balls with a two piece covering are also popular for practice and lower level competition due to their lower cost The nature of the cricket ball slightly varies with its manufacturer White Kookaburra balls are used in one day and Twenty international matches while red Kookaburras are used in test matches played in most of the ten test playing nations except for the West Indies and England who use Dukes and India who use SG balls Cricket balls are traditionally red and red balls are used in Test cricket and First class cricket but proposals to introduce other colours date back at least as early as White balls were introduced when one day matches began being played at night under floodlights as they are more visible at night all professional one day matches are now played with white balls even when they are not played at night The white balls have been found to behave differently from the red balls most notably they swing a lot more during the first half of an innings than the red balls and they deteriorate more quickly Manufacturers claim that white and red balls are manufactured using the same methods and materials other than the dyeing of the leather Another problem associated with white cricket balls used in One Day Internationals is that they quickly become dirty or dull in colour which makes it more difficult for batsmen to sight the ball after overs of use Since October this has been manag ...

# %%
text = word_tokenize(article_text)

# %%
nltk.download('averaged_perceptron_tagger')
tagged = nltk.pos_tag(text)
print(tagged)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Gautam Nair\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('A', 'DT'), ('cricket', 'NN'), ('ball', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), (',', ','), ('solid', 'JJ'), ('ball', 'NN'), ('used', 'VBN'), ('to', 'TO'), ('play', 'VB'), ('cricket', 'NN'), ('.', '.'), ('A', 'DT'), ('cricket', 'NN'), ('ball', 'NN'), ('consists', 'VBZ'), ('of', 'IN'), ('a', 'DT'), ('cork', 'NN'), ('core', 'NN'), ('wound', 'NN'), ('with', 'IN'), ('string', 'VBG'), ('then', 'RB'), ('a', 'DT'), ('leather', 'NN'), ('cover', 'NN'), ('stitched', 'VBN'), ('on', 'IN'), (',', ','), ('and', 'CC'), ('manufacture', 'NN'), ('is', 'VBZ'), ('regulated', 'VBN'), ('by', 'IN'), ('cricket', 'NN'), ('law', 'NN'), ('at', 'IN'), ('first-class', 'JJ'), ('level', 'NN'), ('.', '.'), ('The', 'DT'), ('trajectory', 'NN'), ('of', 'IN'), ('a', 'DT'), ('cricket', 'NN'), ('ball', 'NN'), ('when', 'WRB'), ('bowled', 'VBN'), (',', ','), ('through', 'IN'), ('movement', 'NN'), ('in', 'IN'), ('the', 'DT'), ('air', 'NN'), (',', ','), ('and', 'CC'), ('off', 'IN'), ('the', 'DT'), ('ground', 'NN'), (',', ','), ('is', 'VBZ'), ('influenced', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('action', 'NN'), ('of', 'IN'), ('the', 'DT'), ('bowler', 'NN'), ('and', 'CC'), ('the', 'DT'), ('condition', 'NN'), ('of', 'IN'), ('the', 'DT'), ('ball', 'NN'), ('and', 'CC'), ('the', 'DT'), ('pitch', 'NN'), (',', ','), ('while', 'IN'), ('working', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('cricket', 'NN'), ('ball', 'NN'), ('to', 'TO'), ('obtain', 'VB'), ('optimum', 'JJ'), ('condition', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('key', 'JJ'), ('role', 'NN'), ('of', 'IN'), ('the', 'DT'), ('fielding', 'JJ'), ('side', 'NN'), ('.', '.'), ('The', 'DT'), ('principal', 'JJ'), ('method', 'NN'), ('through', 'IN'), ('which', 'WDT'), ('the', 'DT'), ('batsman', 'NN'), ('scores', 'VBZ'), ('runs', 'NNS'), ('is', 'VBZ'), ('by', 'IN'), ('hitting', 'VBG'), ('the', 'DT'), ('ball', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), ('bat', 'NN'), (',', ','), ('into', 'IN'), ('a', 'DT'), ('position', 'NN'), ('where', 'WRB'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('safe', 'JJ'), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('run', 'NN'), (',', ','), ('or', 'CC'), ('by', 'IN'), ('directing', 'VBG'), ('the', 'DT'), ('ball', 'NN'), ('through', 'IN'), ('or', 'CC'), ('over', 'IN'), ('the', 'DT'), ('boundary', 'JJ'), ('.', '.'), ('Cricket', 'NNP'), ('balls', 'NNS'), ('are', 'VBP'), ('harder', 'JJR'), ('and', 'CC'), ('heavier', 'JJR'), ('than', 'IN'), ('baseballs', 'NNS'), ('.', '.'), ('In', 'IN'), ('day', 'NN'), ('Test', 'NNP'), ('cricket', 'NN'), (',', ','), ('professional', 'JJ'), ('domestic', 'JJ'), ('games', 'NNS'), ('that', 'WDT'), ('spread', 'VBP'), ('over', 'IN'), ('a', 'DT'), ('multitude', 'NN'), ('of', 'IN'), ('days', 'NNS'), (',', ','), ('and', 'CC'), ('almost', 'RB'), ('the', 'DT'), ('entirety', 'NN'), ('of', 'IN'), ('amateur', 'JJ'), ('cricket', 'NN'), (',', ','), ('the', 'DT'), ('traditional', 'JJ'), ('red', 'JJ'), ('cricket', 'NN'), ('ball', 'NN'), ('is', 'VBZ'), ('normally', 'RB'), ('used', 'VBN'), ('.', '.'), ('In', 'IN'), ('many', 'JJ'), ('one', 'CD'), ('day', 'NN'), ('cricket', 'NN'), ('matches', 'NNS'), (',', ','), ('a', 'DT'), ('white', 'JJ'), ('ball', 'NN'), ('is', 'VBZ'), ('used', 'VBN'), ('instead', 'RB'), ('in', 'IN'), ('order', 'NN'), ('to', 'TO'), ('remain', 'VB'), ('visible', 'JJ'), ('under', 'IN'), ('floodlights', 'NNS'), (',', ','), ('and', 'CC'), ('since', 'IN'), ('2010', 'CD'), (',', ','), ('pink', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('introduced', 'VBN'), ('to', 'TO'), ('contrast', 'VB'), ('with', 'IN'), ('players', 'NNS'), ("'", 'POS'), ('white', 'JJ'), ('clothing', 'NN'), ('and', 'CC'), ('for', 'IN'), ('improved', 'JJ'), ('night', 'NN'), ('visibility', 'NN'), ('during', 'IN'), ('day/night', 'JJ'), ('Test', 'NNP'), ('matches', 'NNS'), ('.', '.'), ('Training', 'VBG'), ('balls', 'NNS'), ('of', 'IN'), ('white', 'JJ'), (',', ','), ('red', 'JJ'), ('and', 'CC'), ('pink', 'NN'), ('are', 'VBP'), ('also', 'RB'), ('common', 'JJ'), (',', ','), ('and', 'CC'), ('tennis', 'NN' ...

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(tagged)
print(cs)
# Out:
# (S
#   (NP A/DT cricket/NN)
#   (NP ball/NN)
#   is/VBZ
#   a/DT
#   hard/JJ
#   ,/,
#   (NP solid/JJ ball/NN)
#   used/VBN
#   to/TO
#   play/VB
#   (NP cricket/NN)
#   ./.
#   (NP A/DT cricket/NN)
#   (NP ball/NN)
#   consists/VBZ
#   of/IN
#   (NP a/DT cork/NN)
#   (NP core/NN)
#   (NP wound/NN)
#   with/IN
#   string/VBG
#   then/RB
#   (NP a/DT leather/NN)
#   (NP cover/NN)
#   stitched/VBN
#   on/IN
#   ,/,
#   and/CC
#   (NP manufacture/NN)
#   is/VBZ
#   regulated/VBN
#   by/IN
#   (NP cricket/NN)
#   (NP law/NN)
#   at/IN
#   (NP first-class/JJ level/NN)
#   ./.
#   (NP The/DT trajectory/NN)
#   of/IN
#   (NP a/DT cricket/NN)
#   (NP ball/NN)
#   when/WRB
#   bowled/VBN
#   ,/,
#   through/IN
#   (NP movement/NN)
#   in/IN
#   (NP the/DT air/NN)
#   ,/,
#   and/CC
#   off/IN
#   (NP the/DT ground/NN)
#   ,/,
#   is/VBZ
#   influenced/VBN
#   by/IN
#   (NP the/DT action/NN)
#   of/IN
#   (NP the/DT bowler/NN)
#   and/CC
#   (NP the/DT condition/NN)
#   of/IN
#   (NP the/DT ball/NN)
#   and/CC
#   (NP the/DT pitch/NN)
#   ,/,
#   while/IN
#   working/VBG
#   on/IN
#   (NP the/DT cricket/NN)
#   (NP ball/NN)
#   to/TO
#   obtain/VB
#   (NP optimum/JJ condition/NN)
#   is/VBZ
#   (NP a/DT key/JJ role/NN)
#   of/IN
#   (NP the/DT fielding/JJ side/NN)
#   ./.
#   (NP The/DT principal/JJ method/NN)
#   through/IN
#   which/WDT
#   (NP the/DT batsman/NN)
#   scores/VBZ
#   runs/NNS
#   is/VBZ
#   by/IN
#   hitting/VBG
#   (NP the/DT ball/NN)
#   ,/,
#   with/IN
#   (NP the/DT bat/NN)
#   ,/,
#   into/IN
#   (NP a/DT position/NN)
#   where/WRB
#   it/PRP
#   would/MD
#   be/VB
#   safe/JJ
#   to/TO
#   take/VB
#   (NP a/DT run/NN)
#   ,/,
#   or/CC
#   by/IN
#   directing/VBG
#   (NP the/DT ball/NN)
#   through/IN
#   or/CC
#   over/IN
#   the/DT
#   boundary/JJ
#   ./.
#   Cricket/NNP
#   balls/NNS
#   are/VBP
#   harder/JJR
#   and/CC
#   heavier/JJR
#   than/IN
#   baseballs/NNS
#   ./.
#   In/IN
#   (NP day/NN)
#   Test/NNP
#   (NP cricket/NN)
#   ,/,
#   professional/JJ
#   domestic/JJ
#   games/NNS
#   that/WDT
#   spread/VBP
#   over/IN
#   (NP a/DT multitude/NN)
#   of/IN
#   days/NNS
#   ,/,
#   and/CC
#   almost/RB
#   (NP the/DT entirety/NN)
#   of/IN
#   (NP amateur/JJ cricket/NN)
#   ,/,
#   (NP the/DT traditional/JJ red/JJ cricket/NN)
#   (NP ball/NN)
#   is/VBZ
#   normally/RB
#   used/VBN
#   ./.
#   In/IN
#   many/JJ
#   one/CD
#   (NP day/NN)
#   (NP cricket/NN)
#   matches/NNS
#   ,/,
#   (NP a/DT white/JJ ball/NN)
#   is/VBZ
#   used/VBN
#   instead/RB
#   in/IN
#   (NP order/NN)
#   to/TO
#   remain/VB
#   visible/JJ
#   under/IN
#   floodlights/NNS
#   ,/,
#   and/CC
#   since/IN
#   2010/CD
#   ,/,
#   (NP pink/NN)
#   has/VBZ
#   been/VBN
#   introduced/VBN
#   to/TO
#   contrast/VB
#   with/IN
#   players/NNS
#   '/POS
#   (NP white/JJ clothing/NN)
#   and/CC
#   for/IN
#   (NP improved/JJ night/NN)
#   (NP visibility/NN)
#   during/IN
#   day/night/JJ
#   Test/NNP
#   matches/NNS
#   ./.
#   Training/VBG
#   balls/NNS
#   of/IN
#   white/JJ
#   ,/,
#   red/JJ
#   and/CC
#   (NP pink/NN)
#   are/VBP
#   also/RB
#   common/JJ
#   ,/,
#   and/CC
#   (NP tennis/NN)
#   balls/NNS
#   and/CC
#   other/JJ
#   similar-sized/JJ
#   balls/NNS
#   can/MD
#   be/VB
#   used/VBN
#   for/IN
#   (NP training/NN)
#   or/CC
#   (NP informal/JJ cricket/NN)
#   matches/NNS
#   ./.
#   During/IN
#   (NP cricket/NN)
#   matches/NNS
#   ,/,
#   (NP the/DT quality/NN)
#   of/IN
#   (NP the/DT ball/NN)
#   changes/NNS
#   to/TO
#   (NP a/DT point/NN)
#   where/WRB
#   it/PRP
#   is/VBZ
#   no/RB
#   longer/RBR
#   usable/JJ
#   ,/,
#   and/CC
#   during/IN
#   (NP this/DT decline/NN)
#   its/PRP$
#   properties/NNS
#   (NP alter/NN)
#   and/CC
#   thus/RB
#   can/MD
#   influence/VB
#   (NP the/DT match/NN)
#   ./.
#   Altering/VBG
#   (NP the/DT state/NN)
#   of/IN
#   (NP the/DT cricket/NN)
#   (NP ball/NN)
#   outside/IN
#   the/DT
#   permitted/JJ
#   manners/NNS
#   designated/VBN
#   in/IN
#   the/DT
#   rules/NNS
#   of/IN
#   (NP cricket/NN)
#   is/VBZ
#   prohibited/VBN
#   during/IN
#   (NP a/DT match/NN)
#   ,/,
#   and/CC
#   so-called/JJ
#   ``/``
#   (NP ball/NN)
#   (NP tampering/NN)
#   ''/''
#   has/VBZ
#   resulted/VBN
#   in/IN
#   numerous/JJ
#   controversies/NNS
#   ./.
#   Injuries/NNS
#   and/CC
#   fatalities/NNS
#   have/VBP
#   been/VBN
#   caused/VBN
#   by/IN
#   (NP cricket/NN)
#   balls/NNS
#   during/IN
#   matches/NNS
#   ./.
#   The/DT
#   hazards/NNS
#   posed/VBN
#   by/IN
#   (NP cricket/NN)
#   balls/NNS
#   were/VBD
#   (NP a/DT key/JJ motivator/NN)
#   for/IN
#   (NP the/DT introduction/NN)
#   of/IN
#   (NP protective/JJ equipment/NN)
#   ./.
#   British/JJ
#   Standard/NNP
#   BS/NNP
#   5993/CD
#   specifies/VBZ
#   (NP the/DT construction/NN)
#   details/NNS
#   ,/,
#   dimensions/NNS
#   ,/,
#   (NP quality/NN)
#   and/CC
#   (NP performance/NN)
#   of/IN
#   (NP cricket/NN)
#   balls/NNS
#   ./.
#   (NP A/DT cricket/NN)
#   (NP ball/NN)
#   is/VBZ
#   made/VBN
#   with/IN
#   (NP a/DT core/NN)
#   of/IN
#   (NP cork/NN)
#   ,/,
#   which/WDT
#   is/VBZ
#   layered/VBN
#   with/IN
#   tightly/RB
#   wound/IN
#   (NP string/NN)
#   ,/,
#   and/CC
#   covered/VBN
#   by/IN
#   (NP a/DT leather/NN)
#   (NP case/NN)
#   with/IN
#   a/DT
#   slightly/RB
#   raised/VBN
#   (NP sewn/NN)
#   (NP seam/NN)
#   ./.
#   In/IN
#   (NP a/DT top-quality/NN)
#   (NP ball/NN)
#   suitable/JJ
#   for/IN
#   the/DT
#   highest/JJS
#   levels/NNS
#   of/IN
#   (NP competition/NN)
#   ,/,
#   (NP the/DT covering/NN)
#   is/VBZ
#   constructed/VBN
#   of/IN
#   four/CD
#   pieces/NNS
#   of/IN
#   (NP leather/NN)
#   shaped/VBD
#   similar/JJ
#   to/TO
#   (NP the/DT peel/NN)
#   of/IN
#   (NP a/DT quartered/JJ orange/NN)
#   ,/,
#   but/CC
#   one/CD
#   (NP hemisphere/NN)
#   is/VBZ
#   rotated/VBN
#   by/IN
#   90/CD
#   degrees/NNS
#   with/IN
#   (NP respect/NN)
#   to/TO
#   the/DT
#   other/JJ
#   ./.
#   The/DT
#   ``/``
#   (NP equator/NN)
#   ''/''
#   of/IN
#   (NP the/DT ball/NN)
#   is/VBZ
#   stitched/VBN
#   with/IN
#   (NP string/NN)
#   to/TO
#   form/VB
#   (NP the/DT ball/NN)
#   's/POS
#   (NP prominent/JJ seam/NN)
#   ,/,
#   with/IN
#   six/CD
#   rows/NNS
#   of/IN
#   stitches/NNS
#   ./.
#   The/DT
#   remaining/VBG
#   two/CD
#   joins/NNS
#   between/IN
#   (NP the/DT leather/NN)
#   pieces/NNS
#   are/VBP
#   stitched/VBN
#   internally/RB
#   forming/VBG
#   (NP the/DT quarter/NN)
#   (NP seam/NN)
#   ./.
#   Lower-quality/NNP
#   balls/NNS
#   with/IN
#   (NP a/DT two-piece/JJ covering/NN)
#   are/VBP
#   also/RB
#   popular/JJ
#   for/IN
#   (NP practice/NN)
#   and/CC
#   (NP lower-level/JJ competition/NN)
#   due/JJ
#   to/TO
#   their/PRP$
#   lower/JJR
#   (NP cost/NN)
#   ./.
#   (NP The/DT nature/NN)
#   of/IN
#   (NP the/DT cricket/NN)
#   (NP ball/NN)
#   slightly/RB
#   varies/VBZ
#   with/IN
#   its/PRP$
#   (NP manufacturer/NN)
#   ./.
#   White/NNP
#   Kookaburra/NNP
#   balls/NNS
#   are/VBP
#   used/VBN
#   in/IN
#   one-day/JJ
#   and/CC
#   Twenty20/NNP
#   international/JJ
#   matches/NNS
#   ,/,
#   while/IN
#   red/JJ
#   Kookaburras/NNP
#   are/VBP
#   used/VBN
#   in/IN
#   (NP test/NN)
#   matches/NNS
#   played/VBN
#   in/IN
#   most/JJS
#   of/IN
#   the/DT
#   ten/JJ
#   test-playing/JJ
#   nations/NNS
#   ,/,
#   except/IN
#   for/IN
#   the/DT
#   West/NNP
#   Indies/NNPS
#   and/CC
#   England/NNP
#   ,/,
#   who/WP
#   use/VBP
#   Dukes/NNP
#   ,/,
#   and/CC
#   India/NNP
#   ,/,
#   who/WP
#   use/VBP
#   SG/NNP
#   balls/NNS
#   ./.
#   Cricket/NNP
#   balls/NNS
#   are/VBP
#   traditionally/RB
#   red/JJ
#   ,/,
#   and/CC
#   red/JJ
#   balls/NNS
#   are/VBP
#   used/VBN
#   in/IN
#   Test/NNP
#   (NP cricket/NN)
#   and/CC
#   First-class/NNP
#   (NP cricket/NN)
#   but/CC
#   proposals/NNS
#   to/TO
#   introduce/VB
#   (NP other/JJ colours/NN)
#   (NP date/NN)
#   back/RB
#   at/IN
#   least/JJS
#   as/RB
#   early/RB
#   as/IN
#   1937/CD
#   ./.
#   White/NNP
#   balls/NNS
#   were/VBD
#   introduced/VBN
#   when/WRB
#   one-day/JJ
#   matches/NNS
#   began/VBD
#   being/VBG
#   played/VBN
#   at/IN
#   (NP night/NN)
#   under/IN
#   floodlights/NNS
#   ,/,
#   as/IN
#   they/PRP
#   are/VBP
#   more/RBR
#   visible/JJ
#   at/IN
#   (NP night/NN)
#   ;/:
#   all/DT
#   professional/JJ
#   one-day/JJ
#   matches/NNS
#   are/VBP
#   now/RB
#   played/VBN
#   with/IN
#   white/JJ
#   balls/NNS
#   ,/,
#   even/RB
#   when/WRB
#   they/PRP
#   are/VBP
#   not/RB
#   played/VBN
#   at/IN
#   (NP night/NN)
#   ./.
#   The/DT
#   white/JJ
#   balls/NNS
#   have/VBP
#   been/VBN
#   found/VBN
#   to/TO
#   behave/VB
#   differently/RB
#   from/IN
#   the/DT
#   red/JJ
#   balls/NNS
#   :/:
#   most/JJS
#   notably/RB
#   ,/,
#   they/PRP
#   swing/VBP
#   (NP a/DT lot/NN)
#   more/RBR
#   during/IN
#   (NP the/DT first/JJ half/NN)
#   of/IN
#   (NP an/DT innings/NN)
#   than/IN
#   the/DT
#   red/JJ
#   balls/NNS
#   ,/,
#   and/CC
#   they/PRP
#   deteriorate/VBP
#   more/RBR
#   quickly/RB
#   ./.
#   Manufacturers/NNS
#   claim/VBP
#   that/IN
#   white/JJ
#   and/CC
#   red/JJ
#   balls/NNS
#   are/VBP
#   manufactured/VBN
#   using/VBG
#   the/DT
#   same/JJ
#   methods/NNS
#   and/CC
#   materials/NNS
#   ,/,
#   other/JJ
#   than/IN
#   (NP the/DT dyeing/NN)
#   of/IN
#   (NP the/DT leather/NN)
#   ./.
#   (NP Another/DT problem/NN)
#   associated/VBN
#   with/IN
#   (NP white/JJ cricket/NN)
#   balls/NNS
#   used/VBN
#   in/IN
#   One/CD
#   Day/NNP
#   Internationals/NNP
#   is/VBZ
#   that/IN
#   they/PRP
#   quickly/RB
#   become/VBP
#   dirty/JJ
#   or/CC
#   dull/JJ
#   in/IN
#   (NP colour/NN)
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   more/RBR
#   difficult/JJ
#   for/IN
#   batsmen/NNS
#   to/TO
#   sight/VB
#   (NP the/DT ball/NN)
#   after/IN
#   30-40/JJ
#   overs/NNS
#   of/IN
#   (NP use/NN)
#   ./.
#   Since/IN
#   October/NNP
#   2012/CD
#   ,/,
#   this/DT
#   has/VBZ
#   been/VBN
#   managed/VBN
#   by/IN
#   (NP the/DT use/NN)
#   of/IN
#   two/CD
#   new/JJ
#   white/JJ
#   balls/NNS
#   in/IN
#   each/DT
#   innings/NNS
#   ,/,
#   with/IN
#   (NP a/DT different/JJ ball/NN)
#   used/VBN
#   from/IN
#   each/DT
#   bowling/VBG
#   (NP end/NN)
#   ;/:
#   (NP the/DT same/JJ strategy/NN)
#   was/VBD
#   used/VBN
#   in/IN
#   the/DT
#   1992/CD
#   and/CC
#   1996/CD
#   Cricket/NNP
#   World/NNP
#   Cups/NNP
#   ./.
#   Between/NNP
#   October/NNP
#   2007/CD
#   and/CC
#   October/NNP
#   2012/CD
#   ,/,
#   (NP the/DT issue/NN)
#   had/VBD
#   been/VBN
#   managed/VBN
#   using/VBG
#   one/CD
#   (NP new/JJ ball/NN)
#   from/IN
#   (NP the/DT start/NN)
#   of/IN
#   the/DT
#   innings/NNS
#   ,/,
#   then/RB
#   swapping/VBG
#   it/PRP
#   at/IN
#   (NP the/DT end/NN)
#   of/IN
#   the/DT
#   34th/CD
#   over/IN
#   with/IN
#   a/DT
#   ``/``
#   (NP reconditioned/JJ ball/NN)
#   ''/''
#   ,/,
#   which/WDT
#   was/VBD
#   neither/DT
#   new/JJ
#   nor/CC
#   too/RB
#   dirty/JJ
#   to/TO
#   see/VB
#   ./.
#   Before/IN
#   October/NNP
#   2007/CD
#   ,/,
#   except/IN
#   during/IN
#   1992/CD
#   and/CC
#   1996/CD
#   World/NNP
#   Cups/NNP
#   ,/,
#   only/RB
#   one/CD
#   (NP ball/NN)
#   was/VBD
#   used/VBN
#   during/IN
#   (NP an/DT innings/NN)
#   of/IN
#   an/DT
#   ODI/NNP
#   and/CC
#   it/PRP
#   was/VBD
#   at/IN
#   the/DT
#   umpires/NNS
#   '/POS
#   (NP discretion/NN)
#   to/TO
#   change/VB
#   (NP the/DT ball/NN)
#   if/IN
#   it/PRP
#   was/VBD
#   difficult/JJ
#   to/TO
#   see/VB
#   ./.
#   Pink/VB
#   balls/NNS
#   were/VBD
#   developed/VBN
#   in/IN
#   the/DT
#   2000s/CD
#   to/TO
#   enable/VB
#   Tests/NNS
#   and/CC
#   (NP first-class/NN)
#   matches/NNS
#   played/VBD
#   at/IN
#   (NP night/NN)
#   ./.
#   (NP The/DT red/JJ ball/NN)
#   is/VBZ
#   unsuited/VBN
#   to/TO
#   (NP night/NN)
#   tests/NNS
#   due/JJ
#   to/TO
#   (NP poor/JJ visibility/NN)
#   ,/,
#   and/CC
#   (NP the/DT white/JJ ball/NN)
#   is/VBZ
#   unsuited/VBN
#   to/TO
#   (NP first-class/NN)
#   (NP cricket/NN)
#   because/IN
#   it/PRP
#   deteriorates/VBZ
#   rapidly/RB
#   and/CC
#   can/MD
#   not/RB
#   be/VB
#   used/VBN
#   for/IN
#   eighty/JJ
#   overs/NNS
#   as/IN
#   specified/VBN
#   in/IN
#   the/DT
#   rules/NNS
#   ,/,
#   so/IN
#   (NP the/DT pink/NN)
#   (NP ball/NN)
#   was/VBD
#   designed/VBN
#   to/TO
#   provide/VB
#   (NP a/DT satisfactory/JJ compromise/NN)
#   on/IN
#   both/DT
#   issues/NNS
#   ./.
#   It/PRP
#   is/VBZ
#   still/RB
#   considered/VBN
#   more/RBR
#   difficult/JJ
#   to/TO
#   see/VB
#   than/IN
#   (NP a/DT white/JJ ball/NN)
#   ;/:
#   and/CC
#   (NP the/DT leather/NN)
#   is/VBZ
#   more/RBR
#   heavily/RB
#   dyed/VBN
#   than/IN
#   (NP a/DT red/JJ ball/NN)
#   ,/,
#   which/WDT
#   better/RBR
#   preserves/VBZ
#   its/PRP$
#   (NP colour/NN)
#   and/CC
#   (NP visibility/NN)
#   as/IN
#   it/PRP
#   wears/VBZ
#   but/CC
#   also/RB
#   gives/VBZ
#   it/PRP
#   slightly/RB
#   (NP different/JJ wear/NN)
#   characteristics/NNS
#   ./.
#   It/PRP
#   has/VBZ
#   performed/VBN
#   well/RB
#   enough/RB
#   in/IN
#   testing/VBG
#   and/CC
#   (NP first-class/JJ cricket/NN)
#   to/TO
#   be/VB
#   approved/VBN
#   for/IN
#   (NP use/NN)
#   in/IN
#   (NP international/JJ cricket/NN)
#   ./.
#   (NP A/DT pink/NN)
#   (NP ball/NN)
#   was/VBD
#   used/VBN
#   for/IN
#   (NP the/DT first/JJ time/NN)
#   in/IN
#   (NP an/DT international/JJ match/NN)
#   in/IN
#   July/NNP
#   2009/CD
#   when/WRB
#   the/DT
#   England/NNP
#   Women/NNP
#   's/POS
#   (NP team/NN)
#   defeated/VBD
#   Australia/NNP
#   in/IN
#   (NP a/DT one-day/JJ match/NN)
#   at/IN
#   Wormsley/NNP
#   ,/,
#   and/CC
#   (NP a/DT pink/NN)
#   (NP ball/NN)
#   was/VBD
#   used/VBN
#   in/IN
#   a/DT
#   day-night/JJ
#   Test/NNP
#   (NP match/NN)
#   for/IN
#   (NP the/DT first/JJ time/NN)
#   in/IN
#   November/NNP
#   2015/CD
#   ./.
#   Other/JJ
#   colours/NNS
#   were/VBD
#   also/RB
#   experimented/VBN
#   with/IN
#   ,/,
#   such/JJ
#   as/IN
#   yellow/JJ
#   and/CC
#   (NP orange/NN)
#   (/(
#   glowing/VBG
#   (NP composite/NN)
#   )/)
#   ,/,
#   for/IN
#   improved/VBN
#   (NP night/NN)
#   (NP visibility/NN)
#   ,/,
#   but/CC
#   pink/VBP
#   proved/VBN
#   to/TO
#   be/VB
#   (NP the/DT preferred/JJ option/NN)
#   ./.
#   As/IN
#   of/IN
#   2014/CD
#   ,/,
#   (NP the/DT ball/NN)
#   used/VBN
#   in/IN
#   Test/NNP
#   (NP match/NN)
#   (NP cricket/NN)
#   in/IN
#   England/NNP
#   had/VBD
#   a/DT
#   UK/NNP
#   recommended/VBD
#   (NP retail/JJ price/NN)
#   of/IN
#   (NP £100/NN)
#   ./.
#   In/IN
#   (NP test/NN)
#   (NP match/NN)
#   (NP cricket/NN)
#   (NP this/DT ball/NN)
#   is/VBZ
#   used/VBN
#   for/IN
#   (NP a/DT minimum/NN)
#   of/IN
#   80/CD
#   overs/NNS
#   (/(
#   theoretically/RB
#   five/CD
#   hours/NNS
#   and/CC
#   twenty/JJ
#   minutes/NNS
#   of/IN
#   (NP play/NN)
#   )/)
#   ,/,
#   after/IN
#   which/WDT
#   (NP the/DT fielding/NN)
#   (NP side/NN)
#   has/VBZ
#   (NP the/DT option/NN)
#   of/IN
#   using/VBG
#   (NP a/DT new/JJ ball/NN)
#   ./.
#   In/IN
#   professional/JJ
#   one/CD
#   (NP day/NN)
#   (NP cricket/NN)
#   ,/,
#   at/IN
#   least/JJS
#   two/CD
#   new/JJ
#   balls/NNS
#   are/VBP
#   used/VBN
#   for/IN
#   (NP each/DT match/NN)
#   ./.
#   Amateur/JJ
#   cricketers/NNS
#   often/RB
#   have/VBP
#   to/TO
#   use/VB
#   old/JJ
#   balls/NNS
#   ,/,
#   or/CC
#   cheap/JJ
#   substitutes/NNS
#   ,/,
#   in/IN
#   which/WDT
#   (NP case/NN)
#   the/DT
#   changes/NNS
#   in/IN
#   (NP the/DT condition/NN)
#   of/IN
#   (NP the/DT ball/NN)
#   may/MD
#   be/VB
#   different/JJ
#   from/IN
#   (NP professional/JJ cricket/NN)
#   ./.
#   There/EX
#   are/VBP
#   three/CD
#   main/JJ
#   manufacturers/NNS
#   of/IN
#   (NP cricket/NN)
#   balls/NNS
#   used/VBN
#   in/IN
#   international/JJ
#   matches/NNS
#   :/:
#   Kookaburra/NNP
#   ,/,
#   Dukes/NNP
#   and/CC
#   SG/NNP
#   ./.
#   (NP The/DT manufacturer/NN)
#   of/IN
#   the/DT
#   red/JJ
#   (/(
#   or/CC
#   pink/VB
#   )/)
#   balls/NNS
#   used/VBN
#   for/IN
#   Tests/NNS
#   varies/NNS
#   depending/VBG
#   on/IN
#   (NP location/NN)
#   :/:
#   India/NNP
#   uses/VBZ
#   SG/NNP
#   ;/:
#   England/NNP
#   ,/,
#   Ireland/NNP
#   and/CC
#   the/DT
#   West/NNP
#   Indies/NNPS
#   use/VBP
#   Dukes/NNP
#   ;/:
#   and/CC
#   all/DT
#   other/JJ
#   countries/NNS
#   use/VBP
#   Kookaburra/NNP
#   ./.
#   The/DT
#   different/JJ
#   manufacturers/NNS
#   '/POS
#   balls/NNS
#   behave/VBP
#   differently/RB
#   :/:
#   for/IN
#   (NP instance/NN)
#   Dukes/NNP
#   balls/NNS
#   have/VBP
#   (NP a/DT prouder/NN)
#   (NP seam/NN)
#   and/CC
#   will/MD
#   tend/VB
#   to/TO
#   swing/VBG
#   more/JJR
#   than/IN
#   Kookaburra/NNP
#   balls/NNS
#   –/VBP
#   providing/VBG
#   (NP a/DT home/NN)
#   (NP advantage/NN)
#   when/WRB
#   playing/VBG
#   against/IN
#   (NP a/DT team/NN)
#   (NP unfamiliar/NN)
#   with/IN
#   (NP the/DT ball/NN)
#   ./.
#   All/DT
#   limited/JJ
#   overs/NNS
#   international/JJ
#   matches/NNS
#   ,/,
#   regardless/RB
#   of/IN
#   (NP location/NN)
#   ,/,
#   are/VBP
#   played/VBN
#   with/IN
#   white/JJ
#   Kookaburra/NNP
#   balls/NNS
#   ./.
#   White/NNP
#   Dukes/NNP
#   balls/NNS
#   were/VBD
#   used/VBN
#   at/IN
#   the/DT
#   1999/CD
#   Cricket/NNP
#   World/NNP
#   Cup/NNP
#   ,/,
#   but/CC
#   (NP the/DT ball/NN)
#   behaved/VBD
#   more/RBR
#   erratically/RB
#   than/IN
#   the/DT
#   Kookaburra/NNP
#   and/CC
#   white/JJ
#   Dukes/NNS
#   have/VBP
#   not/RB
#   been/VBN
#   used/VBN
#   since/IN
#   ./.
#   Domestic/JJ
#   competitions/NNS
#   may/MD
#   use/VB
#   (NP a/DT domestic/JJ manufacturer/NN)
#   :/:
#   for/IN
#   (NP example/NN)
#   ,/,
#   Pakistan/NNP
#   uses/VBZ
#   Grays/NNP
#   balls/NNS
#   in/IN
#   its/PRP$
#   first-class/JJ
#   competitions/NNS
#   ./.
#   Cricket/NNP
#   balls/NNS
#   can/MD
#   be/VB
#   bowled/VBN
#   at/IN
#   close/RB
#   to/TO
#   160/CD
#   km/h/NNS
#   (/(
#   100/CD
#   (NP mph/NN)
#   )/)
#   by/IN
#   (NP pace/NN)
#   bowlers/NNS
#   and/CC
#   made/VBD
#   to/TO
#   deviate/VB
#   from/IN
#   (NP a/DT straight/JJ course/NN)
#   ,/,
#   both/DT
#   in/IN
#   (NP the/DT air/NN)
#   (/(
#   known/VBN
#   as/IN
#   'swinging/VBG
#   '/''
#   )/)
#   and/CC
#   off/IN
#   (NP the/DT ground/NN)
#   (/(
#   known/VBN
#   as/IN
#   'seaming/VBG
#   '/''
#   )/)
#   ./.
#   (NP A/DT spin/JJ bowler/NN)
#   imparts/NNS
#   lateral/JJ
#   revolutions/NNS
#   on/IN
#   (NP the/DT ball/NN)
#   at/IN
#   (NP the/DT point/NN)
#   of/IN
#   (NP delivery/NN)
#   ,/,
#   so/IN
#   that/IN
#   when/WRB
#   it/PRP
#   bounces/VBZ
#   it/PRP
#   deviates/VBZ
#   from/IN
#   (NP a/DT straight/JJ course/NN)
#   ./.
#   As/IN
#   (NP cricket/NN)
#   bats/NNS
#   have/VBP
#   become/VBN
#   (NP thicker/NN)
#   ,/,
#   (NP the/DT ball/NN)
#   can/MD
#   now/RB
#   be/VB
#   hit/VBN
#   well/RB
#   over/IN
#   100/CD
#   metres/NNS
#   before/IN
#   touching/VBG
#   (NP the/DT ground/NN)
#   ./.
#   Cricket/NNP
#   (NP commentator/NN)
#   and/CC
#   former/JJ
#   Test/NNP
#   (NP bowler/NN)
#   Simon/NNP
#   Doull/NNP
#   noted/VBD
#   that/IN
#   (NP cricket/NN)
#   balls/NNS
#   produced/VBN
#   after/IN
#   Cricket/NNP
#   World/NNP
#   Cup/NNP
#   2015/CD
#   produced/VBD
#   (NP a/DT lot/NN)
#   less/JJR
#   swing/VBG
#   (NP regardless/NN)
#   of/IN
#   (NP manufacturer/NN)
#   ./.
#   This/DT
#   was/VBD
#   said/VBD
#   to/TO
#   be/VB
#   apparent/JJ
#   in/IN
#   2017/CD
#   ICC/NNP
#   Champions/NNP
#   Trophy/NNP
#   ,/,
#   even/RB
#   on/IN
#   traditionally/RB
#   swing-friendly/JJ
#   British/JJ
#   pitches/NNS
#   ,/,
#   particularly/RB
#   with/IN
#   white/JJ
#   balls/NNS
#   ,/,
#   but/CC
#   the/DT
#   former/JJ
#   West/NNP
#   Indian/NNP
#   (NP bowler/NN)
#   Ian/NNP
#   Bishop/NNP
#   was/VBD
#   unwilling/VBG
#   to/TO
#   support/VB
#   this/DT
#   ./.
#   In/IN
#   Test/NNP
#   (NP cricket/NN)
#   ,/,
#   (NP a/DT new/JJ ball/NN)
#   is/VBZ
#   used/VBN
#   at/IN
#   (NP the/DT start/NN)
#   of/IN
#   each/DT
#   innings/NNS
#   in/IN
#   (NP a/DT match/NN)
#   ./.
#   In/IN
#   Limited/NNP
#   Over/NNP
#   Internationals/NNP
#   ,/,
#   two/CD
#   new/JJ
#   balls/NNS
#   ,/,
#   one/CD
#   from/IN
#   (NP each/DT end/NN)
#   ,/,
#   are/VBP
#   used/VBN
#   at/IN
#   (NP the/DT start/NN)
#   of/IN
#   each/DT
#   innings/NNS
#   ./.
#   (NP A/DT cricket/NN)
#   (NP ball/NN)
#   may/MD
#   not/RB
#   be/VB
#   replaced/VBN
#   except/IN
#   under/IN
#   specific/JJ
#   conditions/NNS
#   described/VBN
#   in/IN
#   the/DT
#   Laws/NNP
#   of/IN
#   Cricket/NNP
#   :/:
#   (NP The/DT ball/NN)
#   is/VBZ
#   not/RB
#   replaced/VBN
#   if/IN
#   it/PRP
#   is/VBZ
#   hit/VBN
#   into/IN
#   (NP the/DT crowd/NN)
#   -/:
#   (NP the/DT crowd/NN)
#   must/MD
#   return/VB
#   it/PRP
#   ./.
#   If/IN
#   (NP the/DT ball/NN)
#   is/VBZ
#   damaged/VBN
#   ,/,
#   lost/VBN
#   ,/,
#   or/CC
#   illegally/RB
#   modified/VBN
#   ,/,
#   it/PRP
#   will/MD
#   be/VB
#   replaced/VBN
#   by/IN
#   (NP a/DT used/JJ ball/NN)
#   in/IN
#   (NP similar/JJ condition/NN)
#   to/TO
#   the/DT
#   replaced/VBN
#   (NP ball/NN)
#   ./.
#   (NP A/DT new/JJ ball/NN)
#   can/MD
#   only/RB
#   be/VB
#   used/VBN
#   after/IN
#   (NP the/DT specified/JJ minimum/JJ number/NN)
#   of/IN
#   overs/NNS
#   have/VBP
#   been/VBN
#   bowled/VBN
#   with/IN
#   (NP the/DT old/JJ one/NN)
#   ./.
#   Because/IN
#   (NP a/DT single/JJ ball/NN)
#   is/VBZ
#   used/VBN
#   for/IN
#   (NP an/DT extended/JJ period/NN)
#   of/IN
#   (NP play/NN)
#   ,/,
#   its/PRP$
#   (NP surface/NN)
#   wears/NNS
#   down/RB
#   and/CC
#   becomes/VBZ
#   rough/JJ
#   ./.
#   The/DT
#   bowlers/NNS
#   may/MD
#   polish/VB
#   it/PRP
#   whenever/WRB
#   they/PRP
#   can/MD
#   ,/,
#   usually/RB
#   by/IN
#   rubbing/VBG
#   it/PRP
#   on/IN
#   their/PRP$
#   trousers/NNS
#   ,/,
#   producing/VBG
#   (NP the/DT characteristic/JJ red/JJ stain/NN)
#   that/WDT
#   can/MD
#   often/RB
#   be/VB
#   seen/VBN
#   there/RB
#   ./.
#   However/RB
#   ,/,
#   they/PRP
#   will/MD
#   usually/RB
#   only/RB
#   polish/JJ
#   one/CD
#   (NP side/NN)
#   of/IN
#   (NP the/DT ball/NN)
#   ,/,
#   in/IN
#   (NP order/NN)
#   to/TO
#   create/VB
#   'swing/VBG
#   '/''
#   as/IN
#   it/PRP
#   travels/VBZ
#   through/IN
#   (NP the/DT air/NN)
#   ./.
#   They/PRP
#   may/MD
#   apply/VB
#   (NP saliva/NN)
#   or/CC
#   (NP sweat/NN)
#   to/TO
#   (NP the/DT ball/NN)
#   as/IN
#   they/PRP
#   polish/VBP
#   it/PRP
#   ./.
#   (NP The/DT seam/NN)
#   of/IN
#   (NP a/DT cricket/NN)
#   (NP ball/NN)
#   can/MD
#   also/RB
#   be/VB
#   used/VBN
#   to/TO
#   produce/VB
#   different/JJ
#   trajectories/NNS
#   through/IN
#   (NP the/DT air/NN)
#   ,/,
#   with/IN
#   (NP the/DT technique/NN)
#   known/VBN
#   as/IN
#   swing/VBG
#   (NP bowling/NN)
#   ,/,
#   or/CC
#   to/TO
#   produce/VB
#   (NP sideways/JJ movement/NN)
#   as/IN
#   it/PRP
#   bounces/VBZ
#   off/IN
#   (NP the/DT pitch/NN)
#   ,/,
#   with/IN
#   (NP the/DT technique/NN)
#   known/VBN
#   as/IN
#   (NP seam/NN)
#   (NP bowling/NN)
#   ./.
#   Since/IN
#   (NP the/DT condition/NN)
#   of/IN
#   (NP the/DT cricket/NN)
#   (NP ball/NN)
#   is/VBZ
#   crucial/JJ
#   to/TO
#   (NP the/DT amount/NN)
#   of/IN
#   (NP movement/NN)
#   through/IN
#   (NP the/DT air/NN)
#   (NP a/DT bowler/NN)
#   can/MD
#   produce/VB
#   ,/,
#   the/DT
#   laws/NNS
#   governing/VBG
#   what/WP
#   players/NNS
#   may/MD
#   and/CC
#   may/MD
#   not/RB
#   do/VB
#   to/TO
#   (NP the/DT ball/NN)
#   are/VBP
#   specific/JJ
#   and/CC
#   rigorously/RB
#   enforced/VBN
#   ./.
#   The/DT
#   umpires/NNS
#   will/MD
#   inspect/VB
#   (NP the/DT ball/NN)
#   frequently/RB
#   during/IN
#   (NP a/DT match/NN)
#   ./.
#   If/IN
#   (NP the/DT ball/NN)
#   is/VBZ
#   out/IN
#   of/IN
#   (NP shape/NN)
#   due/JJ
#   to/TO
#   (NP normal/JJ wear/NN)
#   and/CC
#   tear/VB
#   due/JJ
#   to/TO
#   batting/VBG
#   and/CC
#   ball/VB
#   hitting/VBG
#   (NP the/DT pitch/NN)
#   ,/,
#   (NP a/DT ball/NN)
#   of/IN
#   (NP similar/JJ usage/NN)
#   (NP rate/NN)
#   and/CC
#   (NP condition/NN)
#   will/MD
#   be/VB
#   replaced/VBN
#   :/:
#   (NP e.g/NN)
#   ./.
#   (NP a/DT ball/NN)
#   about/IN
#   30/CD
#   overs/NNS
#   old/JJ
#   will/MD
#   be/VB
#   replaced/VBN
#   by/IN
#   (NP a/DT ball/NN)
#   about/IN
#   (NP the/DT same/JJ age/NN)
#   ./.
#   It/PRP
#   is/VBZ
#   illegal/JJ
#   for/IN
#   (NP a/DT player/NN)
#   to/TO
#   :/:
#   Despite/IN
#   these/DT
#   rules/NNS
#   ,/,
#   it/PRP
#   can/MD
#   be/VB
#   tempting/VBG
#   for/IN
#   players/NNS
#   to/TO
#   gain/VB
#   (NP an/DT advantage/NN)
#   by/IN
#   breaking/VBG
#   them/PRP
#   ./.
#   There/EX
#   have/VBP
#   been/VBN
#   (NP a/DT handful/NN)
#   of/IN
#   incidents/NNS
#   of/IN
#   (NP so-called/JJ ball/NN)
#   (NP tampering/NN)
#   at/IN
#   the/DT
#   highest/JJS
#   levels/NNS
#   of/IN
#   (NP cricket/NN)
#   ./.
#   (NP A/DT new/JJ cricket/NN)
#   (NP ball/NN)
#   is/VBZ
#   harder/JJR
#   than/IN
#   a/DT
#   worn/JJ
#   one/CD
#   ,/,
#   and/CC
#   is/VBZ
#   preferred/VBN
#   by/IN
#   (NP fast/NN)
#   bowlers/NNS
#   because/IN
#   of/IN
#   (NP the/DT speed/NN)
#   and/CC
#   (NP bounce/NN)
#   of/IN
#   (NP the/DT ball/NN)
#   off/IN
#   (NP the/DT pitch/NN)
#   ./.
#   Older/JJR
#   balls/NNS
#   tend/VBP
#   to/TO
#   spin/VB
#   more/JJR
#   as/IN
#   (NP the/DT roughness/NN)
#   grips/VBZ
#   (NP the/DT pitch/NN)
#   more/RBR
#   when/WRB
#   (NP the/DT ball/NN)
#   bounces/NNS
#   ,/,
#   so/RB
#   spin/JJ
#   bowlers/NNS
#   prefer/VBP
#   to/TO
#   use/VB
#   (NP a/DT worn/JJ ball/NN)
#   ,/,
#   though/IN
#   (NP a/DT ball/NN)
#   of/IN
#   about/IN
#   8–10/CD
#   overs/NNS
#   old/JJ
#   is/VBZ
#   still/RB
#   useful/JJ
#   to/TO
#   (NP a/DT spinner/NN)
#   as/IN
#   it/PRP
#   can/MD
#   get/VB
#   more/JJR
#   (NP drift/NN)
#   in/IN
#   (NP the/DT air/NN)
#   ./.
#   Uneven/VBN
#   wear/VBP
#   on/IN
#   older/JJR
#   balls/NNS
#   may/MD
#   also/RB
#   make/VB
#   (NP reverse/NN)
#   swing/VBG
#   possible/JJ
#   ./.
#   (NP A/DT captain/NN)
#   may/MD
#   delay/VB
#   (NP the/DT request/NN)
#   for/IN
#   (NP a/DT new/JJ ball/NN)
#   if/IN
#   she/he/JJ
#   prefers/NNS
#   to/TO
#   have/VB
#   (NP spin/NN)
#   bowlers/NNS
#   operating/VBG
#   ,/,
#   but/CC
#   usually/RB
#   asks/VBZ
#   for/IN
#   (NP the/DT new/JJ ball/NN)
#   soon/RB
#   after/IN
#   it/PRP
#   becomes/VBZ
#   available/JJ
#   ./.
#   Cricket/NNP
#   balls/NNS
#   are/VBP
#   hard/JJ
#   and/CC
#   potentially/RB
#   lethal/JJ
#   ,/,
#   so/RB
#   most/JJS
#   of/IN
#   (NP today/NN)
#   's/POS
#   batsmen/NNS
#   and/CC
#   close/JJ
#   fielders/NNS
#   often/RB
#   wear/VBP
#   (NP protective/JJ equipment/NN)
#   ./.
#   Cricket/NNP
#   (NP ball/NN)
#   injuries/NNS
#   are/VBP
#   fairly/RB
#   frequent/JJ
#   ,/,
#   including/VBG
#   (NP eye/NN)
#   (/(
#   with/IN
#   some/DT
#   players/NNS
#   having/VBG
#   lost/VBN
#   eyes/NNS
#   )/)
#   ,/,
#   (NP head/NN)
#   and/CC
#   (NP face/NN)
#   ,/,
#   (NP finger/NN)
#   and/CC
#   (NP toe/NN)
#   ,/,
#   teeth/NNS
#   and/CC
#   testicular/JJ
#   injuries/NNS
#   ./.
#   Frederick/NNP
#   ,/,
#   Prince/NNP
#   of/IN
#   Wales/NNP
#   (/(
#   1707–1751/CD
#   )/)
#   is/VBZ
#   often/RB
#   said/VBD
#   to/TO
#   have/VB
#   died/VBN
#   of/IN
#   complications/NNS
#   after/IN
#   being/VBG
#   hit/VBN
#   by/IN
#   (NP a/DT cricket/NN)
#   (NP ball/NN)
#   ,/,
#   although/IN
#   (NP the/DT connection/NN)
#   between/IN
#   (NP the/DT incident/NN)
#   and/CC
#   his/PRP$
#   (NP actual/JJ cause/NN)
#   of/IN
#   (NP death/NN)
#   is/VBZ
#   unproven/JJ
#   ./.
#   Glamorgan/NNP
#   (NP player/NN)
#   Roger/NNP
#   Davis/NNP
#   was/VBD
#   seriously/RB
#   injured/VBN
#   by/IN
#   (NP a/DT ball/NN)
#   in/IN
#   1971/CD
#   when/WRB
#   he/PRP
#   was/VBD
#   hit/VBN
#   on/IN
#   (NP the/DT head/NN)
#   while/IN
#   fielding/VBG
#   ./.
#   (NP The/DT Indian/JJ batsman/NN)
#   Nariman/NNP
#   'Nari/NNP
#   '/POS
#   Contractor/NNP
#   had/VBD
#   to/TO
#   retire/VB
#   from/IN
#   (NP the/DT game/NN)
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   (NP the/DT head/NN)
#   by/IN
#   (NP a/DT ball/NN)
#   in/IN
#   the/DT
#   West/NNP
#   Indies/NNPS
#   in/IN
#   1962/CD
#   ./.
#   In/IN
#   1998/CD
#   ,/,
#   (NP Indian/JJ cricketer/NN)
#   Raman/NNP
#   Lamba/NNP
#   died/VBD
#   when/WRB
#   (NP a/DT cricket/NN)
#   (NP ball/NN)
#   hit/VBD
#   his/PRP$
#   (NP head/NN)
#   in/IN
#   (NP a/DT club/NN)
#   (NP match/NN)
#   in/IN
#   Dhaka/NNP
#   ./.
#   Lamba/NNP
#   was/VBD
#   fielding/VBG
#   at/IN
#   forward/RB
#   (NP short/JJ leg/NN)
#   without/IN
#   (NP a/DT helmet/NN)
#   when/WRB
#   (NP a/DT ball/NN)
#   struck/VBN
#   by/IN
#   (NP batsman/NN)
#   Mehrab/NNP
#   Hossain/NNP
#   hit/VBD
#   him/PRP
#   hard/VB
#   on/IN
#   (NP the/DT head/NN)
#   and/CC
#   rebounded/VBD
#   to/TO
#   wicket-keeper/JJ
#   Khaled/NNP
#   Mashud/NNP
#   ./.
#   (NP A/DT cricket/NN)
#   (NP umpire/NN)
#   ,/,
#   Alcwyn/NNP
#   Jenkins/NNP
#   ,/,
#   died/VBD
#   in/IN
#   2009/CD
#   in/IN
#   Swansea/NNP
#   ,/,
#   Wales/NNP
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   (NP the/DT head/NN)
#   by/IN
#   (NP a/DT ball/NN)
#   thrown/VBN
#   by/IN
#   (NP a/DT fielder/NN)
#   ./.
#   On/IN
#   27/CD
#   October/NNP
#   2013/CD
#   ,/,
#   South/NNP
#   African/NNP
#   (NP cricketer/NN)
#   Darryn/NNP
#   Randall/NNP
#   died/VBD
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   (NP the/DT head/NN)
#   by/IN
#   (NP the/DT ball/NN)
#   while/IN
#   batting/VBG
#   ./.
#   He/PRP
#   collapsed/VBD
#   immediately/RB
#   and/CC
#   was/VBD
#   rushed/VBN
#   to/TO
#   the/DT
#   Alice/NNP
#   Hospital/NNP
#   ,/,
#   but/CC
#   (NP the/DT medical/JJ staff/NN)
#   could/MD
#   not/RB
#   revive/VB
#   him/PRP
#   ./.
#   In/IN
#   November/NNP
#   2014/CD
#   ,/,
#   Australia/NNP
#   and/CC
#   South/NNP
#   Australia/NNP
#   (NP batsman/NN)
#   Phillip/NNP
#   Hughes/NNP
#   died/VBD
#   at/IN
#   (NP the/DT age/NN)
#   of/IN
#   25/CD
#   at/IN
#   a/DT
#   Sydney/NNP
#   (NP hospital/NN)
#   after/IN
#   he/PRP
#   was/VBD
#   hit/VBN
#   on/IN
#   (NP the/DT side/NN)
#   of/IN
#   (NP the/DT neck/NN)
#   by/IN
#   (NP a/DT bouncer/NN)
#   bowled/VBN
#   by/IN
#   Sean/NNP
#   Abbott/NNP
#   during/IN
#   a/DT
#   Sheffield/NNP
#   Shield/NNP
#   (NP game/NN)
#   ./.
#   (NP The/DT same/JJ week/NN)
#   ,/,
#   Hillel/NNP
#   Oscar/NNP
#   ,/,
#   (NP an/DT umpire/NN)
#   and/CC
#   (NP former/JJ captain/NN)
#   of/IN
#   Israel/NNP
#   's/POS
#   (NP national/JJ cricket/NN)
#   (NP team/NN)
#   ,/,
#   died/VBD
#   after/IN
#   being/VBG
#   hit/VBN
#   in/IN
#   (NP the/DT neck/NN)
#   by/IN
#   (NP a/DT ball/NN)
#   ./.
#   On/IN
#   14/CD
#   August/NNP
#   2017/CD
#   ,/,
#   Zubair/NNP
#   Ahmed/NNP
#   died/VBD
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   (NP the/DT head/NN)
#   while/IN
#   batting/VBG
#   in/IN
#   (NP a/DT club/NN)
#   (NP match/NN)
#   played/VBN
#   in/IN
#   the/DT
#   Mardan/NNP
#   District/NNP
#   ,/,
#   Khyber/NNP
#   Pakhtunkhwa/NNP
#   ,/,
#   Pakistan/NNP
#   ./.
#   Sometimes/RB
#   alternatives/NNS
#   to/TO
#   (NP a/DT real/JJ cricket/NN)
#   (NP ball/NN)
#   may/MD
#   be/VB
#   preferred/VBN
#   for/IN
#   reasons/NNS
#   of/IN
#   (NP safety/NN)
#   ,/,
#   (NP availability/NN)
#   and/CC
#   (NP cost/NN)
#   ./.
#   Examples/NNP
#   include/VBP
#   (NP a/DT tennis/NN)
#   (NP ball/NN)
#   and/CC
#   (NP a/DT plastic/JJ version/NN)
#   of/IN
#   (NP the/DT cricket/NN)
#   (NP ball/NN)
#   ./.
#   Many/JJ
#   casual/JJ
#   players/NNS
#   use/VBP
#   (NP a/DT tennis/NN)
#   (NP ball/NN)
#   wrapped/VBD
#   in/IN
#   layers/NNS
#   of/IN
#   (NP some/DT type/NN)
#   of/IN
#   (NP adhesive/JJ tape/NN)
#   (/(
#   often/RB
#   (NP electrical/JJ tape/NN)
#   )/)
#   ,/,
#   which/WDT
#   makes/VBZ
#   the/DT
#   relatively/RB
#   (NP soft/JJ tennis/NN)
#   (NP ball/NN)
#   (NP harder/NN)
#   and/CC
#   (NP smoother/NN)
#   ./.
#   This/DT
#   is/VBZ
#   commonly/RB
#   referred/VBN
#   to/TO
#   as/IN
#   (NP a/DT tape/NN)
#   (NP ball/NN)
#   ./.
#   (NP A/DT common/JJ variant/NN)
#   is/VBZ
#   to/TO
#   tape/VB
#   only/RB
#   half/PDT
#   (NP the/DT tennis/NN)
#   (NP ball/NN)
#   ,/,
#   to/TO
#   provide/VB
#   two/CD
#   different/JJ
#   sides/NNS
#   and/CC
#   make/VB
#   it/PRP
#   easy/JJ
#   to/TO
#   bowl/VB
#   with/IN
#   prodigious/JJ
#   amounts/NNS
#   of/IN
#   (NP swing/NN)
#   ./.
#   Younger/JJR
#   players/NNS
#   often/RB
#   use/VBP
#   (NP either/DT tennis/NN)
#   balls/VBZ
#   or/CC
#   (NP an/DT air-filled/JJ plastic/NN)
#   'windball/POS
#   '/''
#   for/IN
#   (NP safety/NN)
#   reasons/NNS
#   before/IN
#   using/VBG
#   the/DT
#   'hard/NNP
#   '/POS
#   (NP cricket/NN)
#   (NP ball/NN)
#   after/IN
#   (NP a/DT certain/JJ age/NN)
#   :/:
#   (NP windball/NN)
#   (NP cricket/NN)
#   is/VBZ
#   also/RB
#   (NP a/DT popular/JJ sport/NN)
#   in/IN
#   its/PRP$
#   (NP own/JJ right/NN)
#   ./.
#   They/PRP
#   might/MD
#   also/RB
#   use/VB
#   (NP an/DT 'IncrediBall/NN)
#   '/''
#   or/CC
#   (NP an/DT 'Aeroball/NN)
#   '/POS
#   (NP whilst/NN)
#   making/VBG
#   (NP the/DT step/NN)
#   between/IN
#   windballs/NNS
#   and/CC
#   'hard/NNP
#   '/POS
#   (NP cricket/NN)
#   balls/NNS
#   ./.
#   These/DT
#   balls/NNS
#   are/VBP
#   designed/VBN
#   to/TO
#   mimic/VB
#   (NP the/DT feel/NN)
#   ,/,
#   (NP speed/NN)
#   and/CC
#   (NP bounce/NN)
#   of/IN
#   (NP a/DT regular/JJ hard/JJ ball/NN)
#   ,/,
#   but/CC
#   soften/VBD
#   when/WRB
#   coming/VBG
#   in/IN
#   (NP contact/NN)
#   with/IN
#   objects/NNS
#   at/IN
#   (NP high/JJ speed/NN)
#   ,/,
#   reducing/VBG
#   (NP the/DT risk/NN)
#   of/IN
#   (NP injury/NN)
#   ./.)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

# %%
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('A', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('a', 'DT', 'O'),
#  ('hard', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('solid', 'JJ', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('used', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('play', 'VB', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('consists', 'VBZ', 'O'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('cork', 'NN', 'I-NP'),
#  ('core', 'NN', 'B-NP'),
#  ('wound', 'NN', 'B-NP'),
#  ('with', 'IN', 'O'),
#  ('string', 'VBG', 'O'),
#  ('then', 'RB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('leather', 'NN', 'I-NP'),
#  ('cover', 'NN', 'B-NP'),
#  ('stitched', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('manufacture', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('regulated', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('law', 'NN', 'B-NP'),
#  ('at', 'IN', 'O'),
#  ('first-class', 'JJ', 'B-NP'),
#  ('level', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('trajectory', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('when', 'WRB', 'O'),
#  ('bowled', 'VBN', 'O'),
#  (',', ',', 'O'),
#  ('through', 'IN', 'O'),
#  ('movement', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('air', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('off', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ground', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('influenced', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('action', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('bowler', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('condition', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pitch', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('while', 'IN', 'O'),
#  ('working', 'VBG', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('obtain', 'VB', 'O'),
#  ('optimum', 'JJ', 'B-NP'),
#  ('condition', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('key', 'JJ', 'I-NP'),
#  ('role', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('fielding', 'JJ', 'I-NP'),
#  ('side', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('principal', 'JJ', 'I-NP'),
#  ('method', 'NN', 'I-NP'),
#  ('through', 'IN', 'O'),
#  ('which', 'WDT', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('batsman', 'NN', 'I-NP'),
#  ('scores', 'VBZ', 'O'),
#  ('runs', 'NNS', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('by', 'IN', 'O'),
#  ('hitting', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('with', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('bat', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('into', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('position', 'NN', 'I-NP'),
#  ('where', 'WRB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('would', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('safe', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('take', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('run', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('or', 'CC', 'O'),
#  ('by', 'IN', 'O'),
#  ('directing', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('through', 'IN', 'O'),
#  ('or', 'CC', 'O'),
#  ('over', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('boundary', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('harder', 'JJR', 'O'),
#  ('and', 'CC', 'O'),
#  ('heavier', 'JJR', 'O'),
#  ('than', 'IN', 'O'),
#  ('baseballs', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('day', 'NN', 'B-NP'),
#  ('Test', 'NNP', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('professional', 'JJ', 'O'),
#  ('domestic', 'JJ', 'O'),
#  ('games', 'NNS', 'O'),
#  ('that', 'WDT', 'O'),
#  ('spread', 'VBP', 'O'),
#  ('over', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('multitude', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('days', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('almost', 'RB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('entirety', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('amateur', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('traditional', 'JJ', 'I-NP'),
#  ('red', 'JJ', 'I-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('normally', 'RB', 'O'),
#  ('used', 'VBN', 'O'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('many', 'JJ', 'O'),
#  ('one', 'CD', 'O'),
#  ('day', 'NN', 'B-NP'),
#  ('cricket', 'NN', 'B-NP'),
#  ('matches', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('white', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('used', 'VBN', 'O'),
#  ('instead', 'RB', 'O'),
#  ('in', 'IN', 'O'),
#  ('order', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('remain', 'VB', 'O'),
#  ('visible', 'JJ', 'O'),
#  ('under', 'IN', 'O'),
#  ('floodlights', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('since', 'IN', 'O'),
#  ('2010', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('pink', 'NN', 'B-NP'),
#  ('has', 'VBZ', 'O'),
#  ('been', 'VBN', 'O'),
#  ('introduced', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('contrast', 'VB', 'O'),
#  ('with', 'IN', 'O'),
#  ('players', 'NNS', 'O'),
#  ("'", 'POS', 'O'),
#  ('white', 'JJ', 'B-NP'),
#  ('clothing', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('for', 'IN', 'O'),
#  ('improved', 'JJ', 'B-NP'),
#  ('night', 'NN', 'I-NP'),
#  ('visibility', 'NN', 'B-NP'),
#  ('during', 'IN', 'O'),
#  ('day/night', 'JJ', 'O'),
#  ('Test', 'NNP', 'O'),
#  ('matches', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Training', 'VBG', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('white', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('red', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('pink', 'NN', 'B-NP'),
#  ('are', 'VBP', 'O'),
#  ('also', 'RB', 'O'),
#  ('common', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('tennis', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('other', 'JJ', 'O'),
#  ('similar-sized', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('can', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('training', 'NN', 'B-NP'),
#  ('or', 'CC', 'O'),
#  ('informal', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('matches', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('During', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('matches', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('quality', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('changes', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('point', 'NN', 'I-NP'),
#  ('where', 'WRB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('no', 'RB', 'O'),
#  ('longer', 'RBR', 'O'),
#  ('usable', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('during', 'IN', 'O'),
#  ('this', 'DT', 'B-NP'),
#  ('decline', 'NN', 'I-NP'),
#  ('its', 'PRP$', 'O'),
#  ('properties', 'NNS', 'O'),
#  ('alter', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('thus', 'RB', 'O'),
#  ('can', 'MD', 'O'),
#  ('influence', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('match', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Altering', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('state', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('outside', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('permitted', 'JJ', 'O'),
#  ('manners', 'NNS', 'O'),
#  ('designated', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('rules', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('prohibited', 'VBN', 'O'),
#  ('during', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('match', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('so-called', 'JJ', 'O'),
#  ('``', '``', 'O'),
#  ('ball', 'NN', 'B-NP'),
#  ('tampering', 'NN', 'B-NP'),
#  ("''", "''", 'O'),
#  ('has', 'VBZ', 'O'),
#  ('resulted', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('numerous', 'JJ', 'O'),
#  ('controversies', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Injuries', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('fatalities', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('been', 'VBN', 'O'),
#  ('caused', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('during', 'IN', 'O'),
#  ('matches', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('hazards', 'NNS', 'O'),
#  ('posed', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('key', 'JJ', 'I-NP'),
#  ('motivator', 'NN', 'I-NP'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('introduction', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('protective', 'JJ', 'B-NP'),
#  ('equipment', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('British', 'JJ', 'O'),
#  ('Standard', 'NNP', 'O'),
#  ('BS', 'NNP', 'O'),
#  ('5993', 'CD', 'O'),
#  ('specifies', 'VBZ', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('construction', 'NN', 'I-NP'),
#  ('details', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('dimensions', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('quality', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('performance', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('made', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('core', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('cork', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('layered', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('tightly', 'RB', 'O'),
#  ('wound', 'IN', 'O'),
#  ('string', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('covered', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('leather', 'NN', 'I-NP'),
#  ('case', 'NN', 'B-NP'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('slightly', 'RB', 'O'),
#  ('raised', 'VBN', 'O'),
#  ('sewn', 'NN', 'B-NP'),
#  ('seam', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('top-quality', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('suitable', 'JJ', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('highest', 'JJS', 'O'),
#  ('levels', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('competition', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('covering', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('constructed', 'VBN', 'O'),
#  ('of', 'IN', 'O'),
#  ('four', 'CD', 'O'),
#  ('pieces', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('leather', 'NN', 'B-NP'),
#  ('shaped', 'VBD', 'O'),
#  ('similar', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('peel', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('quartered', 'JJ', 'I-NP'),
#  ('orange', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('one', 'CD', 'O'),
#  ('hemisphere', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('rotated', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('90', 'CD', 'O'),
#  ('degrees', 'NNS', 'O'),
#  ('with', 'IN', 'O'),
#  ('respect', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'O'),
#  ('other', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('``', '``', 'O'),
#  ('equator', 'NN', 'B-NP'),
#  ("''", "''", 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('stitched', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('string', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('form', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ("'s", 'POS', 'O'),
#  ('prominent', 'JJ', 'B-NP'),
#  ('seam', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('with', 'IN', 'O'),
#  ('six', 'CD', 'O'),
#  ('rows', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('stitches', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('remaining', 'VBG', 'O'),
#  ('two', 'CD', 'O'),
#  ('joins', 'NNS', 'O'),
#  ('between', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('leather', 'NN', 'I-NP'),
#  ('pieces', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('stitched', 'VBN', 'O'),
#  ('internally', 'RB', 'O'),
#  ('forming', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('quarter', 'NN', 'I-NP'),
#  ('seam', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Lower-quality', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('two-piece', 'JJ', 'I-NP'),
#  ('covering', 'NN', 'I-NP'),
#  ('are', 'VBP', 'O'),
#  ('also', 'RB', 'O'),
#  ('popular', 'JJ', 'O'),
#  ('for', 'IN', 'O'),
#  ('practice', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('lower-level', 'JJ', 'B-NP'),
#  ('competition', 'NN', 'I-NP'),
#  ('due', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('their', 'PRP$', 'O'),
#  ('lower', 'JJR', 'O'),
#  ('cost', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('nature', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('slightly', 'RB', 'O'),
#  ('varies', 'VBZ', 'O'),
#  ('with', 'IN', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('manufacturer', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('White', 'NNP', 'O'),
#  ('Kookaburra', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('one-day', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('Twenty20', 'NNP', 'O'),
#  ('international', 'JJ', 'O'),
#  ('matches', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('while', 'IN', 'O'),
#  ('red', 'JJ', 'O'),
#  ('Kookaburras', 'NNP', 'O'),
#  ('are', 'VBP', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('test', 'NN', 'B-NP'),
#  ('matches', 'NNS', 'O'),
#  ('played', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('most', 'JJS', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('ten', 'JJ', 'O'),
#  ('test-playing', 'JJ', 'O'),
#  ('nations', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('except', 'IN', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('West', 'NNP', 'O'),
#  ('Indies', 'NNPS', 'O'),
#  ('and', 'CC', 'O'),
#  ('England', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('who', 'WP', 'O'),
#  ('use', 'VBP', 'O'),
#  ('Dukes', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('India', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('who', 'WP', 'O'),
#  ('use', 'VBP', 'O'),
#  ('SG', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('traditionally', 'RB', 'O'),
#  ('red', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('red', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Test', 'NNP', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('First-class', 'NNP', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('but', 'CC', 'O'),
#  ('proposals', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('introduce', 'VB', 'O'),
#  ('other', 'JJ', 'B-NP'),
#  ('colours', 'NN', 'I-NP'),
#  ('date', 'NN', 'B-NP'),
#  ('back', 'RB', 'O'),
#  ('at', 'IN', 'O'),
#  ('least', 'JJS', 'O'),
#  ('as', 'RB', 'O'),
#  ('early', 'RB', 'O'),
#  ('as', 'IN', 'O'),
#  ('1937', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('White', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('introduced', 'VBN', 'O'),
#  ('when', 'WRB', 'O'),
#  ('one-day', 'JJ', 'O'),
#  ('matches', 'NNS', 'O'),
#  ('began', 'VBD', 'O'),
#  ('being', 'VBG', 'O'),
#  ('played', 'VBN', 'O'),
#  ('at', 'IN', 'O'),
#  ('night', 'NN', 'B-NP'),
#  ('under', 'IN', 'O'),
#  ('floodlights', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('as', 'IN', 'O'),
#  ('they', 'PRP', 'O'),
#  ('are', 'VBP', 'O'),
#  ('more', 'RBR', 'O'),
#  ('visible', 'JJ', 'O'),
#  ('at', 'IN', 'O'),
#  ('night', 'NN', 'B-NP'),
#  (';', ':', 'O'),
#  ('all', 'DT', 'O'),
#  ('professional', 'JJ', 'O'),
#  ('one-day', 'JJ', 'O'),
#  ('matches', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('now', 'RB', 'O'),
#  ('played', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('white', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('even', 'RB', 'O'),
#  ('when', 'WRB', 'O'),
#  ('they', 'PRP', 'O'),
#  ('are', 'VBP', 'O'),
#  ('not', 'RB', 'O'),
#  ('played', 'VBN', 'O'),
#  ('at', 'IN', 'O'),
#  ('night', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('white', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('been', 'VBN', 'O'),
#  ('found', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('behave', 'VB', 'O'),
#  ('differently', 'RB', 'O'),
#  ('from', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('red', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  (':', ':', 'O'),
#  ('most', 'JJS', 'O'),
#  ('notably', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('they', 'PRP', 'O'),
#  ('swing', 'VBP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('lot', 'NN', 'I-NP'),
#  ('more', 'RBR', 'O'),
#  ('during', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('first', 'JJ', 'I-NP'),
#  ('half', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('innings', 'NN', 'I-NP'),
#  ('than', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('red', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('they', 'PRP', 'O'),
#  ('deteriorate', 'VBP', 'O'),
#  ('more', 'RBR', 'O'),
#  ('quickly', 'RB', 'O'),
#  ('.', '.', 'O'),
#  ('Manufacturers', 'NNS', 'O'),
#  ('claim', 'VBP', 'O'),
#  ('that', 'IN', 'O'),
#  ('white', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('red', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('manufactured', 'VBN', 'O'),
#  ('using', 'VBG', 'O'),
#  ('the', 'DT', 'O'),
#  ('same', 'JJ', 'O'),
#  ('methods', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('materials', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('other', 'JJ', 'O'),
#  ('than', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('dyeing', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('leather', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Another', 'DT', 'B-NP'),
#  ('problem', 'NN', 'I-NP'),
#  ('associated', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('white', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('balls', 'NNS', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('One', 'CD', 'O'),
#  ('Day', 'NNP', 'O'),
#  ('Internationals', 'NNP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('that', 'IN', 'O'),
#  ('they', 'PRP', 'O'),
#  ('quickly', 'RB', 'O'),
#  ('become', 'VBP', 'O'),
#  ('dirty', 'JJ', 'O'),
#  ('or', 'CC', 'O'),
#  ('dull', 'JJ', 'O'),
#  ('in', 'IN', 'O'),
#  ('colour', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('makes', 'VBZ', 'O'),
#  ('it', 'PRP', 'O'),
#  ('more', 'RBR', 'O'),
#  ('difficult', 'JJ', 'O'),
#  ('for', 'IN', 'O'),
#  ('batsmen', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('sight', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('after', 'IN', 'O'),
#  ('30-40', 'JJ', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('use', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Since', 'IN', 'O'),
#  ('October', 'NNP', 'O'),
#  ('2012', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('this', 'DT', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('been', 'VBN', 'O'),
#  ('managed', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('use', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('two', 'CD', 'O'),
#  ('new', 'JJ', 'O'),
#  ('white', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('each', 'DT', 'O'),
#  ('innings', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('different', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('used', 'VBN', 'O'),
#  ('from', 'IN', 'O'),
#  ('each', 'DT', 'O'),
#  ('bowling', 'VBG', 'O'),
#  ('end', 'NN', 'B-NP'),
#  (';', ':', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('same', 'JJ', 'I-NP'),
#  ('strategy', 'NN', 'I-NP'),
#  ('was', 'VBD', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('1992', 'CD', 'O'),
#  ('and', 'CC', 'O'),
#  ('1996', 'CD', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('World', 'NNP', 'O'),
#  ('Cups', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Between', 'NNP', 'O'),
#  ('October', 'NNP', 'O'),
#  ('2007', 'CD', 'O'),
#  ('and', 'CC', 'O'),
#  ('October', 'NNP', 'O'),
#  ('2012', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('issue', 'NN', 'I-NP'),
#  ('had', 'VBD', 'O'),
#  ('been', 'VBN', 'O'),
#  ('managed', 'VBN', 'O'),
#  ('using', 'VBG', 'O'),
#  ('one', 'CD', 'O'),
#  ('new', 'JJ', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('from', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('start', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('innings', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('then', 'RB', 'O'),
#  ('swapping', 'VBG', 'O'),
#  ('it', 'PRP', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('end', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('34th', 'CD', 'O'),
#  ('over', 'IN', 'O'),
#  ('with', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('``', '``', 'O'),
#  ('reconditioned', 'JJ', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ("''", "''", 'O'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('was', 'VBD', 'O'),
#  ('neither', 'DT', 'O'),
#  ('new', 'JJ', 'O'),
#  ('nor', 'CC', 'O'),
#  ('too', 'RB', 'O'),
#  ('dirty', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('see', 'VB', 'O'),
#  ('.', '.', 'O'),
#  ('Before', 'IN', 'O'),
#  ('October', 'NNP', 'O'),
#  ('2007', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('except', 'IN', 'O'),
#  ('during', 'IN', 'O'),
#  ('1992', 'CD', 'O'),
#  ('and', 'CC', 'O'),
#  ('1996', 'CD', 'O'),
#  ('World', 'NNP', 'O'),
#  ('Cups', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('only', 'RB', 'O'),
#  ('one', 'CD', 'O'),
#  ('ball', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('used', 'VBN', 'O'),
#  ('during', 'IN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('innings', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('an', 'DT', 'O'),
#  ('ODI', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('it', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('umpires', 'NNS', 'O'),
#  ("'", 'POS', 'O'),
#  ('discretion', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('change', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('if', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('difficult', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('see', 'VB', 'O'),
#  ('.', '.', 'O'),
#  ('Pink', 'VB', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('developed', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('2000s', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('enable', 'VB', 'O'),
#  ('Tests', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('first-class', 'NN', 'B-NP'),
#  ('matches', 'NNS', 'O'),
#  ('played', 'VBD', 'O'),
#  ('at', 'IN', 'O'),
#  ('night', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('red', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('unsuited', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('night', 'NN', 'B-NP'),
#  ('tests', 'NNS', 'O'),
#  ('due', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('poor', 'JJ', 'B-NP'),
#  ('visibility', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('white', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('unsuited', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('first-class', 'NN', 'B-NP'),
#  ('cricket', 'NN', 'B-NP'),
#  ('because', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('deteriorates', 'VBZ', 'O'),
#  ('rapidly', 'RB', 'O'),
#  ('and', 'CC', 'O'),
#  ('can', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('eighty', 'JJ', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('as', 'IN', 'O'),
#  ('specified', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('rules', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('so', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pink', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('designed', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('provide', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('satisfactory', 'JJ', 'I-NP'),
#  ('compromise', 'NN', 'I-NP'),
#  ('on', 'IN', 'O'),
#  ('both', 'DT', 'O'),
#  ('issues', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('still', 'RB', 'O'),
#  ('considered', 'VBN', 'O'),
#  ('more', 'RBR', 'O'),
#  ('difficult', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('see', 'VB', 'O'),
#  ('than', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('white', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  (';', ':', 'O'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('leather', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('more', 'RBR', 'O'),
#  ('heavily', 'RB', 'O'),
#  ('dyed', 'VBN', 'O'),
#  ('than', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('red', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('better', 'RBR', 'O'),
#  ('preserves', 'VBZ', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('colour', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('visibility', 'NN', 'B-NP'),
#  ('as', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('wears', 'VBZ', 'O'),
#  ('but', 'CC', 'O'),
#  ('also', 'RB', 'O'),
#  ('gives', 'VBZ', 'O'),
#  ('it', 'PRP', 'O'),
#  ('slightly', 'RB', 'O'),
#  ('different', 'JJ', 'B-NP'),
#  ('wear', 'NN', 'I-NP'),
#  ('characteristics', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('performed', 'VBN', 'O'),
#  ('well', 'RB', 'O'),
#  ('enough', 'RB', 'O'),
#  ('in', 'IN', 'O'),
#  ('testing', 'VBG', 'O'),
#  ('and', 'CC', 'O'),
#  ('first-class', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('be', 'VB', 'O'),
#  ('approved', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('use', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('international', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('pink', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('first', 'JJ', 'I-NP'),
#  ('time', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('international', 'JJ', 'I-NP'),
#  ('match', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('July', 'NNP', 'O'),
#  ('2009', 'CD', 'O'),
#  ('when', 'WRB', 'O'),
#  ('the', 'DT', 'O'),
#  ('England', 'NNP', 'O'),
#  ('Women', 'NNP', 'O'),
#  ("'s", 'POS', 'O'),
#  ('team', 'NN', 'B-NP'),
#  ('defeated', 'VBD', 'O'),
#  ('Australia', 'NNP', 'O'),
#  ('in', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('one-day', 'JJ', 'I-NP'),
#  ('match', 'NN', 'I-NP'),
#  ('at', 'IN', 'O'),
#  ('Wormsley', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('pink', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('was', 'VBD', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('day-night', 'JJ', 'O'),
#  ('Test', 'NNP', 'O'),
#  ('match', 'NN', 'B-NP'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('first', 'JJ', 'I-NP'),
#  ('time', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('November', 'NNP', 'O'),
#  ('2015', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('Other', 'JJ', 'O'),
#  ('colours', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('also', 'RB', 'O'),
#  ('experimented', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  (',', ',', 'O'),
#  ('such', 'JJ', 'O'),
#  ('as', 'IN', 'O'),
#  ('yellow', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('orange', 'NN', 'B-NP'),
#  ('(', '(', 'O'),
#  ('glowing', 'VBG', 'O'),
#  ('composite', 'NN', 'B-NP'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('for', 'IN', 'O'),
#  ('improved', 'VBN', 'O'),
#  ('night', 'NN', 'B-NP'),
#  ('visibility', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('pink', 'VBP', 'O'),
#  ('proved', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('be', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('preferred', 'JJ', 'I-NP'),
#  ('option', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('As', 'IN', 'O'),
#  ('of', 'IN', 'O'),
#  ('2014', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Test', 'NNP', 'O'),
#  ('match', 'NN', 'B-NP'),
#  ('cricket', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('England', 'NNP', 'O'),
#  ('had', 'VBD', 'O'),
#  ('a', 'DT', 'O'),
#  ('UK', 'NNP', 'O'),
#  ('recommended', 'VBD', 'O'),
#  ('retail', 'JJ', 'B-NP'),
#  ('price', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('£100', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('test', 'NN', 'B-NP'),
#  ('match', 'NN', 'B-NP'),
#  ('cricket', 'NN', 'B-NP'),
#  ('this', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('minimum', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('80', 'CD', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('(', '(', 'O'),
#  ('theoretically', 'RB', 'O'),
#  ('five', 'CD', 'O'),
#  ('hours', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('twenty', 'JJ', 'O'),
#  ('minutes', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('play', 'NN', 'B-NP'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('after', 'IN', 'O'),
#  ('which', 'WDT', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('fielding', 'NN', 'I-NP'),
#  ('side', 'NN', 'B-NP'),
#  ('has', 'VBZ', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('option', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('using', 'VBG', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('professional', 'JJ', 'O'),
#  ('one', 'CD', 'O'),
#  ('day', 'NN', 'B-NP'),
#  ('cricket', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('at', 'IN', 'O'),
#  ('least', 'JJS', 'O'),
#  ('two', 'CD', 'O'),
#  ('new', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('each', 'DT', 'B-NP'),
#  ('match', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Amateur', 'JJ', 'O'),
#  ('cricketers', 'NNS', 'O'),
#  ('often', 'RB', 'O'),
#  ('have', 'VBP', 'O'),
#  ('to', 'TO', 'O'),
#  ('use', 'VB', 'O'),
#  ('old', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('or', 'CC', 'O'),
#  ('cheap', 'JJ', 'O'),
#  ('substitutes', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('in', 'IN', 'O'),
#  ('which', 'WDT', 'O'),
#  ('case', 'NN', 'B-NP'),
#  ('the', 'DT', 'O'),
#  ('changes', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('condition', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('may', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('different', 'JJ', 'O'),
#  ('from', 'IN', 'O'),
#  ('professional', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('There', 'EX', 'O'),
#  ('are', 'VBP', 'O'),
#  ('three', 'CD', 'O'),
#  ('main', 'JJ', 'O'),
#  ('manufacturers', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('used', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('international', 'JJ', 'O'),
#  ('matches', 'NNS', 'O'),
#  (':', ':', 'O'),
#  ('Kookaburra', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Dukes', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('SG', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('manufacturer', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('red', 'JJ', 'O'),
#  ('(', '(', 'O'),
#  ('or', 'CC', 'O'),
#  ('pink', 'VB', 'O'),
#  (')', ')', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('Tests', 'NNS', 'O'),
#  ('varies', 'NNS', 'O'),
#  ('depending', 'VBG', 'O'),
#  ('on', 'IN', 'O'),
#  ('location', 'NN', 'B-NP'),
#  (':', ':', 'O'),
#  ('India', 'NNP', 'O'),
#  ('uses', 'VBZ', 'O'),
#  ('SG', 'NNP', 'O'),
#  (';', ':', 'O'),
#  ('England', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Ireland', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'O'),
#  ('West', 'NNP', 'O'),
#  ('Indies', 'NNPS', 'O'),
#  ('use', 'VBP', 'O'),
#  ('Dukes', 'NNP', 'O'),
#  (';', ':', 'O'),
#  ('and', 'CC', 'O'),
#  ('all', 'DT', 'O'),
#  ('other', 'JJ', 'O'),
#  ('countries', 'NNS', 'O'),
#  ('use', 'VBP', 'O'),
#  ('Kookaburra', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('different', 'JJ', 'O'),
#  ('manufacturers', 'NNS', 'O'),
#  ("'", 'POS', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('behave', 'VBP', 'O'),
#  ('differently', 'RB', 'O'),
#  (':', ':', 'O'),
#  ('for', 'IN', 'O'),
#  ('instance', 'NN', 'B-NP'),
#  ('Dukes', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('prouder', 'NN', 'I-NP'),
#  ('seam', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('will', 'MD', 'O'),
#  ('tend', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('swing', 'VBG', 'O'),
#  ('more', 'JJR', 'O'),
#  ('than', 'IN', 'O'),
#  ('Kookaburra', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('–', 'VBP', 'O'),
#  ('providing', 'VBG', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('home', 'NN', 'I-NP'),
#  ('advantage', 'NN', 'B-NP'),
#  ('when', 'WRB', 'O'),
#  ('playing', 'VBG', 'O'),
#  ('against', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('team', 'NN', 'I-NP'),
#  ('unfamiliar', 'NN', 'B-NP'),
#  ('with', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('All', 'DT', 'O'),
#  ('limited', 'JJ', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('international', 'JJ', 'O'),
#  ('matches', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('regardless', 'RB', 'O'),
#  ('of', 'IN', 'O'),
#  ('location', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('are', 'VBP', 'O'),
#  ('played', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('white', 'JJ', 'O'),
#  ('Kookaburra', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('White', 'NNP', 'O'),
#  ('Dukes', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('used', 'VBN', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('1999', 'CD', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('World', 'NNP', 'O'),
#  ('Cup', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('behaved', 'VBD', 'O'),
#  ('more', 'RBR', 'O'),
#  ('erratically', 'RB', 'O'),
#  ('than', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('Kookaburra', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('white', 'JJ', 'O'),
#  ('Dukes', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('not', 'RB', 'O'),
#  ('been', 'VBN', 'O'),
#  ('used', 'VBN', 'O'),
#  ('since', 'IN', 'O'),
#  ('.', '.', 'O'),
#  ('Domestic', 'JJ', 'O'),
#  ('competitions', 'NNS', 'O'),
#  ('may', 'MD', 'O'),
#  ('use', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('domestic', 'JJ', 'I-NP'),
#  ('manufacturer', 'NN', 'I-NP'),
#  (':', ':', 'O'),
#  ('for', 'IN', 'O'),
#  ('example', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('Pakistan', 'NNP', 'O'),
#  ('uses', 'VBZ', 'O'),
#  ('Grays', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('first-class', 'JJ', 'O'),
#  ('competitions', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('can', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('bowled', 'VBN', 'O'),
#  ('at', 'IN', 'O'),
#  ('close', 'RB', 'O'),
#  ('to', 'TO', 'O'),
#  ('160', 'CD', 'O'),
#  ('km/h', 'NNS', 'O'),
#  ('(', '(', 'O'),
#  ('100', 'CD', 'O'),
#  ('mph', 'NN', 'B-NP'),
#  (')', ')', 'O'),
#  ('by', 'IN', 'O'),
#  ('pace', 'NN', 'B-NP'),
#  ('bowlers', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('made', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('deviate', 'VB', 'O'),
#  ('from', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('straight', 'JJ', 'I-NP'),
#  ('course', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('both', 'DT', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('air', 'NN', 'I-NP'),
#  ('(', '(', 'O'),
#  ('known', 'VBN', 'O'),
#  ('as', 'IN', 'O'),
#  ("'swinging", 'VBG', 'O'),
#  ("'", "''", 'O'),
#  (')', ')', 'O'),
#  ('and', 'CC', 'O'),
#  ('off', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ground', 'NN', 'I-NP'),
#  ('(', '(', 'O'),
#  ('known', 'VBN', 'O'),
#  ('as', 'IN', 'O'),
#  ("'seaming", 'VBG', 'O'),
#  ("'", "''", 'O'),
#  (')', ')', 'O'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('spin', 'JJ', 'I-NP'),
#  ('bowler', 'NN', 'I-NP'),
#  ('imparts', 'NNS', 'O'),
#  ('lateral', 'JJ', 'O'),
#  ('revolutions', 'NNS', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('point', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('delivery', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('so', 'IN', 'O'),
#  ('that', 'IN', 'O'),
#  ('when', 'WRB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('bounces', 'VBZ', 'O'),
#  ('it', 'PRP', 'O'),
#  ('deviates', 'VBZ', 'O'),
#  ('from', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('straight', 'JJ', 'I-NP'),
#  ('course', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('As', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('bats', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('become', 'VBN', 'O'),
#  ('thicker', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('can', 'MD', 'O'),
#  ('now', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('well', 'RB', 'O'),
#  ('over', 'IN', 'O'),
#  ('100', 'CD', 'O'),
#  ('metres', 'NNS', 'O'),
#  ('before', 'IN', 'O'),
#  ('touching', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ground', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('commentator', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('former', 'JJ', 'O'),
#  ('Test', 'NNP', 'O'),
#  ('bowler', 'NN', 'B-NP'),
#  ('Simon', 'NNP', 'O'),
#  ('Doull', 'NNP', 'O'),
#  ('noted', 'VBD', 'O'),
#  ('that', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('produced', 'VBN', 'O'),
#  ('after', 'IN', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('World', 'NNP', 'O'),
#  ('Cup', 'NNP', 'O'),
#  ('2015', 'CD', 'O'),
#  ('produced', 'VBD', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('lot', 'NN', 'I-NP'),
#  ('less', 'JJR', 'O'),
#  ('swing', 'VBG', 'O'),
#  ('regardless', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('manufacturer', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('This', 'DT', 'O'),
#  ('was', 'VBD', 'O'),
#  ('said', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('be', 'VB', 'O'),
#  ('apparent', 'JJ', 'O'),
#  ('in', 'IN', 'O'),
#  ('2017', 'CD', 'O'),
#  ('ICC', 'NNP', 'O'),
#  ('Champions', 'NNP', 'O'),
#  ('Trophy', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('even', 'RB', 'O'),
#  ('on', 'IN', 'O'),
#  ('traditionally', 'RB', 'O'),
#  ('swing-friendly', 'JJ', 'O'),
#  ('British', 'JJ', 'O'),
#  ('pitches', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('particularly', 'RB', 'O'),
#  ('with', 'IN', 'O'),
#  ('white', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('the', 'DT', 'O'),
#  ('former', 'JJ', 'O'),
#  ('West', 'NNP', 'O'),
#  ('Indian', 'NNP', 'O'),
#  ('bowler', 'NN', 'B-NP'),
#  ('Ian', 'NNP', 'O'),
#  ('Bishop', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('unwilling', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('support', 'VB', 'O'),
#  ('this', 'DT', 'O'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('Test', 'NNP', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('used', 'VBN', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('start', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('each', 'DT', 'O'),
#  ('innings', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('match', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('Limited', 'NNP', 'O'),
#  ('Over', 'NNP', 'O'),
#  ('Internationals', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('two', 'CD', 'O'),
#  ('new', 'JJ', 'O'),
#  ('balls', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('one', 'CD', 'O'),
#  ('from', 'IN', 'O'),
#  ('each', 'DT', 'B-NP'),
#  ('end', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('are', 'VBP', 'O'),
#  ('used', 'VBN', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('start', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('each', 'DT', 'O'),
#  ('innings', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('may', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('replaced', 'VBN', 'O'),
#  ('except', 'IN', 'O'),
#  ('under', 'IN', 'O'),
#  ('specific', 'JJ', 'O'),
#  ('conditions', 'NNS', 'O'),
#  ('described', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('Laws', 'NNP', 'O'),
#  ('of', 'IN', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  (':', ':', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('not', 'RB', 'O'),
#  ('replaced', 'VBN', 'O'),
#  ('if', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('into', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('crowd', 'NN', 'I-NP'),
#  ('-', ':', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('crowd', 'NN', 'I-NP'),
#  ('must', 'MD', 'O'),
#  ('return', 'VB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('.', '.', 'O'),
#  ('If', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('damaged', 'VBN', 'O'),
#  (',', ',', 'O'),
#  ('lost', 'VBN', 'O'),
#  (',', ',', 'O'),
#  ('or', 'CC', 'O'),
#  ('illegally', 'RB', 'O'),
#  ('modified', 'VBN', 'O'),
#  (',', ',', 'O'),
#  ('it', 'PRP', 'O'),
#  ('will', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('replaced', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('used', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('similar', 'JJ', 'B-NP'),
#  ('condition', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'O'),
#  ('replaced', 'VBN', 'O'),
#  ('ball', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('can', 'MD', 'O'),
#  ('only', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('used', 'VBN', 'O'),
#  ('after', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('specified', 'JJ', 'I-NP'),
#  ('minimum', 'JJ', 'I-NP'),
#  ('number', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('been', 'VBN', 'O'),
#  ('bowled', 'VBN', 'O'),
#  ('with', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('old', 'JJ', 'I-NP'),
#  ('one', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Because', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('single', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('used', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('extended', 'JJ', 'I-NP'),
#  ('period', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('play', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('surface', 'NN', 'B-NP'),
#  ('wears', 'NNS', 'O'),
#  ('down', 'RB', 'O'),
#  ('and', 'CC', 'O'),
#  ('becomes', 'VBZ', 'O'),
#  ('rough', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('bowlers', 'NNS', 'O'),
#  ('may', 'MD', 'O'),
#  ('polish', 'VB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('whenever', 'WRB', 'O'),
#  ('they', 'PRP', 'O'),
#  ('can', 'MD', 'O'),
#  (',', ',', 'O'),
#  ('usually', 'RB', 'O'),
#  ('by', 'IN', 'O'),
#  ('rubbing', 'VBG', 'O'),
#  ('it', 'PRP', 'O'),
#  ('on', 'IN', 'O'),
#  ('their', 'PRP$', 'O'),
#  ('trousers', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('producing', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('characteristic', 'JJ', 'I-NP'),
#  ('red', 'JJ', 'I-NP'),
#  ('stain', 'NN', 'I-NP'),
#  ('that', 'WDT', 'O'),
#  ('can', 'MD', 'O'),
#  ('often', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('seen', 'VBN', 'O'),
#  ('there', 'RB', 'O'),
#  ('.', '.', 'O'),
#  ('However', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('they', 'PRP', 'O'),
#  ('will', 'MD', 'O'),
#  ('usually', 'RB', 'O'),
#  ('only', 'RB', 'O'),
#  ('polish', 'JJ', 'O'),
#  ('one', 'CD', 'O'),
#  ('side', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('in', 'IN', 'O'),
#  ('order', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('create', 'VB', 'O'),
#  ("'swing", 'VBG', 'O'),
#  ("'", "''", 'O'),
#  ('as', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('travels', 'VBZ', 'O'),
#  ('through', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('air', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('They', 'PRP', 'O'),
#  ('may', 'MD', 'O'),
#  ('apply', 'VB', 'O'),
#  ('saliva', 'NN', 'B-NP'),
#  ('or', 'CC', 'O'),
#  ('sweat', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('as', 'IN', 'O'),
#  ('they', 'PRP', 'O'),
#  ('polish', 'VBP', 'O'),
#  ('it', 'PRP', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('seam', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('can', 'MD', 'O'),
#  ('also', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('used', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('produce', 'VB', 'O'),
#  ('different', 'JJ', 'O'),
#  ('trajectories', 'NNS', 'O'),
#  ('through', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('air', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('with', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('technique', 'NN', 'I-NP'),
#  ('known', 'VBN', 'O'),
#  ('as', 'IN', 'O'),
#  ('swing', 'VBG', 'O'),
#  ('bowling', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('or', 'CC', 'O'),
#  ('to', 'TO', 'O'),
#  ('produce', 'VB', 'O'),
#  ('sideways', 'JJ', 'B-NP'),
#  ('movement', 'NN', 'I-NP'),
#  ('as', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('bounces', 'VBZ', 'O'),
#  ('off', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pitch', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('with', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('technique', 'NN', 'I-NP'),
#  ('known', 'VBN', 'O'),
#  ('as', 'IN', 'O'),
#  ('seam', 'NN', 'B-NP'),
#  ('bowling', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Since', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('condition', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('crucial', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('amount', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('movement', 'NN', 'B-NP'),
#  ('through', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('air', 'NN', 'I-NP'),
#  ('a', 'DT', 'B-NP'),
#  ('bowler', 'NN', 'I-NP'),
#  ('can', 'MD', 'O'),
#  ('produce', 'VB', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'O'),
#  ('laws', 'NNS', 'O'),
#  ('governing', 'VBG', 'O'),
#  ('what', 'WP', 'O'),
#  ('players', 'NNS', 'O'),
#  ('may', 'MD', 'O'),
#  ('and', 'CC', 'O'),
#  ('may', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('do', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('are', 'VBP', 'O'),
#  ('specific', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('rigorously', 'RB', 'O'),
#  ('enforced', 'VBN', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('umpires', 'NNS', 'O'),
#  ('will', 'MD', 'O'),
#  ('inspect', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('frequently', 'RB', 'O'),
#  ('during', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('match', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('If', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('out', 'IN', 'O'),
#  ('of', 'IN', 'O'),
#  ('shape', 'NN', 'B-NP'),
#  ('due', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('normal', 'JJ', 'B-NP'),
#  ('wear', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('tear', 'VB', 'O'),
#  ('due', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('batting', 'VBG', 'O'),
#  ('and', 'CC', 'O'),
#  ('ball', 'VB', 'O'),
#  ('hitting', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pitch', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('similar', 'JJ', 'B-NP'),
#  ('usage', 'NN', 'I-NP'),
#  ('rate', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('condition', 'NN', 'B-NP'),
#  ('will', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('replaced', 'VBN', 'O'),
#  (':', ':', 'O'),
#  ('e.g', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('about', 'IN', 'O'),
#  ('30', 'CD', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('old', 'JJ', 'O'),
#  ('will', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('replaced', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('about', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('same', 'JJ', 'I-NP'),
#  ('age', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('illegal', 'JJ', 'O'),
#  ('for', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('player', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  (':', ':', 'O'),
#  ('Despite', 'IN', 'O'),
#  ('these', 'DT', 'O'),
#  ('rules', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('it', 'PRP', 'O'),
#  ('can', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('tempting', 'VBG', 'O'),
#  ('for', 'IN', 'O'),
#  ('players', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('gain', 'VB', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('advantage', 'NN', 'I-NP'),
#  ('by', 'IN', 'O'),
#  ('breaking', 'VBG', 'O'),
#  ('them', 'PRP', 'O'),
#  ('.', '.', 'O'),
#  ('There', 'EX', 'O'),
#  ('have', 'VBP', 'O'),
#  ('been', 'VBN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('handful', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('incidents', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('so-called', 'JJ', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('tampering', 'NN', 'B-NP'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('highest', 'JJS', 'O'),
#  ('levels', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('harder', 'JJR', 'O'),
#  ('than', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('worn', 'JJ', 'O'),
#  ('one', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('preferred', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('fast', 'NN', 'B-NP'),
#  ('bowlers', 'NNS', 'O'),
#  ('because', 'IN', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('speed', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('bounce', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('off', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pitch', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Older', 'JJR', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('tend', 'VBP', 'O'),
#  ('to', 'TO', 'O'),
#  ('spin', 'VB', 'O'),
#  ('more', 'JJR', 'O'),
#  ('as', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('roughness', 'NN', 'I-NP'),
#  ('grips', 'VBZ', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('pitch', 'NN', 'I-NP'),
#  ('more', 'RBR', 'O'),
#  ('when', 'WRB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('bounces', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('so', 'RB', 'O'),
#  ('spin', 'JJ', 'O'),
#  ('bowlers', 'NNS', 'O'),
#  ('prefer', 'VBP', 'O'),
#  ('to', 'TO', 'O'),
#  ('use', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('worn', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('though', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('about', 'IN', 'O'),
#  ('8–10', 'CD', 'O'),
#  ('overs', 'NNS', 'O'),
#  ('old', 'JJ', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('still', 'RB', 'O'),
#  ('useful', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('spinner', 'NN', 'I-NP'),
#  ('as', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('can', 'MD', 'O'),
#  ('get', 'VB', 'O'),
#  ('more', 'JJR', 'O'),
#  ('drift', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('air', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Uneven', 'VBN', 'O'),
#  ('wear', 'VBP', 'O'),
#  ('on', 'IN', 'O'),
#  ('older', 'JJR', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('may', 'MD', 'O'),
#  ('also', 'RB', 'O'),
#  ('make', 'VB', 'O'),
#  ('reverse', 'NN', 'B-NP'),
#  ('swing', 'VBG', 'O'),
#  ('possible', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('captain', 'NN', 'I-NP'),
#  ('may', 'MD', 'O'),
#  ('delay', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('request', 'NN', 'I-NP'),
#  ('for', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('if', 'IN', 'O'),
#  ('she/he', 'JJ', 'O'),
#  ('prefers', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('have', 'VB', 'O'),
#  ('spin', 'NN', 'B-NP'),
#  ('bowlers', 'NNS', 'O'),
#  ('operating', 'VBG', 'O'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('usually', 'RB', 'O'),
#  ('asks', 'VBZ', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('soon', 'RB', 'O'),
#  ('after', 'IN', 'O'),
#  ('it', 'PRP', 'O'),
#  ('becomes', 'VBZ', 'O'),
#  ('available', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('hard', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('potentially', 'RB', 'O'),
#  ('lethal', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('so', 'RB', 'O'),
#  ('most', 'JJS', 'O'),
#  ('of', 'IN', 'O'),
#  ('today', 'NN', 'B-NP'),
#  ("'s", 'POS', 'O'),
#  ('batsmen', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('close', 'JJ', 'O'),
#  ('fielders', 'NNS', 'O'),
#  ('often', 'RB', 'O'),
#  ('wear', 'VBP', 'O'),
#  ('protective', 'JJ', 'B-NP'),
#  ('equipment', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('Cricket', 'NNP', 'O'),
#  ('ball', 'NN', 'B-NP'),
#  ('injuries', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('fairly', 'RB', 'O'),
#  ('frequent', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('including', 'VBG', 'O'),
#  ('eye', 'NN', 'B-NP'),
#  ('(', '(', 'O'),
#  ('with', 'IN', 'O'),
#  ('some', 'DT', 'O'),
#  ('players', 'NNS', 'O'),
#  ('having', 'VBG', 'O'),
#  ('lost', 'VBN', 'O'),
#  ('eyes', 'NNS', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('head', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('face', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('finger', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('toe', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('teeth', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('testicular', 'JJ', 'O'),
#  ('injuries', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Frederick', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Prince', 'NNP', 'O'),
#  ('of', 'IN', 'O'),
#  ('Wales', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('1707–1751', 'CD', 'O'),
#  (')', ')', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('often', 'RB', 'O'),
#  ('said', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('have', 'VB', 'O'),
#  ('died', 'VBN', 'O'),
#  ('of', 'IN', 'O'),
#  ('complications', 'NNS', 'O'),
#  ('after', 'IN', 'O'),
#  ('being', 'VBG', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('although', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('connection', 'NN', 'I-NP'),
#  ('between', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('incident', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('his', 'PRP$', 'O'),
#  ('actual', 'JJ', 'B-NP'),
#  ('cause', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('death', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('unproven', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('Glamorgan', 'NNP', 'O'),
#  ('player', 'NN', 'B-NP'),
#  ('Roger', 'NNP', 'O'),
#  ('Davis', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('seriously', 'RB', 'O'),
#  ('injured', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('1971', 'CD', 'O'),
#  ('when', 'WRB', 'O'),
#  ('he', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('head', 'NN', 'I-NP'),
#  ('while', 'IN', 'O'),
#  ('fielding', 'VBG', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('Indian', 'JJ', 'I-NP'),
#  ('batsman', 'NN', 'I-NP'),
#  ('Nariman', 'NNP', 'O'),
#  ("'Nari", 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('Contractor', 'NNP', 'O'),
#  ('had', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('retire', 'VB', 'O'),
#  ('from', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('game', 'NN', 'I-NP'),
#  ('after', 'IN', 'O'),
#  ('being', 'VBG', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('head', 'NN', 'I-NP'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('West', 'NNP', 'O'),
#  ('Indies', 'NNPS', 'O'),
#  ('in', 'IN', 'O'),
#  ('1962', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('1998', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('Indian', 'JJ', 'B-NP'),
#  ('cricketer', 'NN', 'I-NP'),
#  ('Raman', 'NNP', 'O'),
#  ('Lamba', 'NNP', 'O'),
#  ('died', 'VBD', 'O'),
#  ('when', 'WRB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('hit', 'VBD', 'O'),
#  ('his', 'PRP$', 'O'),
#  ('head', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('club', 'NN', 'I-NP'),
#  ('match', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('Dhaka', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Lamba', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('fielding', 'VBG', 'O'),
#  ('at', 'IN', 'O'),
#  ('forward', 'RB', 'O'),
#  ('short', 'JJ', 'B-NP'),
#  ('leg', 'NN', 'I-NP'),
#  ('without', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('helmet', 'NN', 'I-NP'),
#  ('when', 'WRB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('struck', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('batsman', 'NN', 'B-NP'),
#  ('Mehrab', 'NNP', 'O'),
#  ('Hossain', 'NNP', 'O'),
#  ('hit', 'VBD', 'O'),
#  ('him', 'PRP', 'O'),
#  ('hard', 'VB', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('head', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('rebounded', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('wicket-keeper', 'JJ', 'O'),
#  ('Khaled', 'NNP', 'O'),
#  ('Mashud', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('umpire', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('Alcwyn', 'NNP', 'O'),
#  ('Jenkins', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('died', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('2009', 'CD', 'O'),
#  ('in', 'IN', 'O'),
#  ('Swansea', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Wales', 'NNP', 'O'),
#  ('after', 'IN', 'O'),
#  ('being', 'VBG', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('head', 'NN', 'I-NP'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('thrown', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('fielder', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('On', 'IN', 'O'),
#  ('27', 'CD', 'O'),
#  ('October', 'NNP', 'O'),
#  ('2013', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('South', 'NNP', 'O'),
#  ('African', 'NNP', 'O'),
#  ('cricketer', 'NN', 'B-NP'),
#  ('Darryn', 'NNP', 'O'),
#  ('Randall', 'NNP', 'O'),
#  ('died', 'VBD', 'O'),
#  ('after', 'IN', 'O'),
#  ('being', 'VBG', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('head', 'NN', 'I-NP'),
#  ('by', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('while', 'IN', 'O'),
#  ('batting', 'VBG', 'O'),
#  ('.', '.', 'O'),
#  ('He', 'PRP', 'O'),
#  ('collapsed', 'VBD', 'O'),
#  ('immediately', 'RB', 'O'),
#  ('and', 'CC', 'O'),
#  ('was', 'VBD', 'O'),
#  ('rushed', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'O'),
#  ('Alice', 'NNP', 'O'),
#  ('Hospital', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('medical', 'JJ', 'I-NP'),
#  ('staff', 'NN', 'I-NP'),
#  ('could', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('revive', 'VB', 'O'),
#  ('him', 'PRP', 'O'),
#  ('.', '.', 'O'),
#  ('In', 'IN', 'O'),
#  ('November', 'NNP', 'O'),
#  ('2014', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('Australia', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('South', 'NNP', 'O'),
#  ('Australia', 'NNP', 'O'),
#  ('batsman', 'NN', 'B-NP'),
#  ('Phillip', 'NNP', 'O'),
#  ('Hughes', 'NNP', 'O'),
#  ('died', 'VBD', 'O'),
#  ('at', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('age', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('25', 'CD', 'O'),
#  ('at', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('Sydney', 'NNP', 'O'),
#  ('hospital', 'NN', 'B-NP'),
#  ('after', 'IN', 'O'),
#  ('he', 'PRP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('side', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('neck', 'NN', 'I-NP'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('bouncer', 'NN', 'I-NP'),
#  ('bowled', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('Sean', 'NNP', 'O'),
#  ('Abbott', 'NNP', 'O'),
#  ('during', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('Sheffield', 'NNP', 'O'),
#  ('Shield', 'NNP', 'O'),
#  ('game', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'B-NP'),
#  ('same', 'JJ', 'I-NP'),
#  ('week', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('Hillel', 'NNP', 'O'),
#  ('Oscar', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('umpire', 'NN', 'I-NP'),
#  ('and', 'CC', 'O'),
#  ('former', 'JJ', 'B-NP'),
#  ('captain', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('Israel', 'NNP', 'O'),
#  ("'s", 'POS', 'O'),
#  ('national', 'JJ', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('team', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('died', 'VBD', 'O'),
#  ('after', 'IN', 'O'),
#  ('being', 'VBG', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('neck', 'NN', 'I-NP'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('ball', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('On', 'IN', 'O'),
#  ('14', 'CD', 'O'),
#  ('August', 'NNP', 'O'),
#  ('2017', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('Zubair', 'NNP', 'O'),
#  ('Ahmed', 'NNP', 'O'),
#  ('died', 'VBD', 'O'),
#  ('after', 'IN', 'O'),
#  ('being', 'VBG', 'O'),
#  ('hit', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('head', 'NN', 'I-NP'),
#  ('while', 'IN', 'O'),
#  ('batting', 'VBG', 'O'),
#  ('in', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('club', 'NN', 'I-NP'),
#  ('match', 'NN', 'B-NP'),
#  ('played', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('Mardan', 'NNP', 'O'),
#  ('District', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Khyber', 'NNP', 'O'),
#  ('Pakhtunkhwa', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Pakistan', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Sometimes', 'RB', 'O'),
#  ('alternatives', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('real', 'JJ', 'I-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('may', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('preferred', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('reasons', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('safety', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('availability', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('cost', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Examples', 'NNP', 'O'),
#  ('include', 'VBP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('tennis', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('plastic', 'JJ', 'I-NP'),
#  ('version', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('cricket', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Many', 'JJ', 'O'),
#  ('casual', 'JJ', 'O'),
#  ('players', 'NNS', 'O'),
#  ('use', 'VBP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('tennis', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('wrapped', 'VBD', 'O'),
#  ('in', 'IN', 'O'),
#  ('layers', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('some', 'DT', 'B-NP'),
#  ('type', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('adhesive', 'JJ', 'B-NP'),
#  ('tape', 'NN', 'I-NP'),
#  ('(', '(', 'O'),
#  ('often', 'RB', 'O'),
#  ('electrical', 'JJ', 'B-NP'),
#  ('tape', 'NN', 'I-NP'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('makes', 'VBZ', 'O'),
#  ('the', 'DT', 'O'),
#  ('relatively', 'RB', 'O'),
#  ('soft', 'JJ', 'B-NP'),
#  ('tennis', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('harder', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('smoother', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('This', 'DT', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('commonly', 'RB', 'O'),
#  ('referred', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('as', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('tape', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('A', 'DT', 'B-NP'),
#  ('common', 'JJ', 'I-NP'),
#  ('variant', 'NN', 'I-NP'),
#  ('is', 'VBZ', 'O'),
#  ('to', 'TO', 'O'),
#  ('tape', 'VB', 'O'),
#  ('only', 'RB', 'O'),
#  ('half', 'PDT', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('tennis', 'NN', 'I-NP'),
#  ('ball', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('to', 'TO', 'O'),
#  ('provide', 'VB', 'O'),
#  ('two', 'CD', 'O'),
#  ('different', 'JJ', 'O'),
#  ('sides', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('make', 'VB', 'O'),
#  ('it', 'PRP', 'O'),
#  ('easy', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('bowl', 'VB', 'O'),
#  ('with', 'IN', 'O'),
#  ('prodigious', 'JJ', 'O'),
#  ('amounts', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('swing', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Younger', 'JJR', 'O'),
#  ('players', 'NNS', 'O'),
#  ('often', 'RB', 'O'),
#  ('use', 'VBP', 'O'),
#  ('either', 'DT', 'B-NP'),
#  ('tennis', 'NN', 'I-NP'),
#  ('balls', 'VBZ', 'O'),
#  ('or', 'CC', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('air-filled', 'JJ', 'I-NP'),
#  ('plastic', 'NN', 'I-NP'),
#  ("'windball", 'POS', 'O'),
#  ("'", "''", 'O'),
#  ('for', 'IN', 'O'),
#  ('safety', 'NN', 'B-NP'),
#  ('reasons', 'NNS', 'O'),
#  ('before', 'IN', 'O'),
#  ('using', 'VBG', 'O'),
#  ('the', 'DT', 'O'),
#  ("'hard", 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('ball', 'NN', 'B-NP'),
#  ('after', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('certain', 'JJ', 'I-NP'),
#  ('age', 'NN', 'I-NP'),
#  (':', ':', 'O'),
#  ('windball', 'NN', 'B-NP'),
#  ('cricket', 'NN', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('also', 'RB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('popular', 'JJ', 'I-NP'),
#  ('sport', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('own', 'JJ', 'B-NP'),
#  ('right', 'NN', 'I-NP'),
#  ('.', '.', 'O'),
#  ('They', 'PRP', 'O'),
#  ('might', 'MD', 'O'),
#  ('also', 'RB', 'O'),
#  ('use', 'VB', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ("'IncrediBall", 'NN', 'I-NP'),
#  ("'", "''", 'O'),
#  ('or', 'CC', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ("'Aeroball", 'NN', 'I-NP'),
#  ("'", 'POS', 'O'),
#  ('whilst', 'NN', 'B-NP'),
#  ('making', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('step', 'NN', 'I-NP'),
#  ('between', 'IN', 'O'),
#  ('windballs', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ("'hard", 'NNP', 'O'),
#  ("'", 'POS', 'O'),
#  ('cricket', 'NN', 'B-NP'),
#  ('balls', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('These', 'DT', 'O'),
#  ('balls', 'NNS', 'O'),
#  ('are', 'VBP', 'O'),
#  ('designed', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('mimic', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('feel', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('speed', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('bounce', 'NN', 'B-NP'),
#  ('of', 'IN', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('regular', 'JJ', 'I-NP'),
#  ('hard', 'JJ', 'I-NP'),
#  ('ball', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('soften', 'VBD', 'O'),
#  ('when', 'WRB', 'O'),
#  ('coming', 'VBG', 'O'),
#  ('in', 'IN', 'O'),
#  ('contact', 'NN', 'B-NP'),
#  ('with', 'IN', 'O'),
#  ('objects', 'NNS', 'O'),
#  ('at', 'IN', 'O'),
#  ('high', 'JJ', 'B-NP'),
#  ('speed', 'NN', 'I-NP'),
#  (',', ',', 'O'),
#  ('reducing', 'VBG', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('risk', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('injury', 'NN', 'B-NP'),
#  ('.', '.', 'O')]

# %%
ne_tree = nltk.ne_chunk(nltk.pos_tag(word_tokenize(article_text)))
print(ne_tree)
# Out:
# (S
#   A/DT
#   cricket/NN
#   ball/NN
#   is/VBZ
#   a/DT
#   hard/JJ
#   ,/,
#   solid/JJ
#   ball/NN
#   used/VBN
#   to/TO
#   play/VB
#   cricket/NN
#   ./.
#   A/DT
#   cricket/NN
#   ball/NN
#   consists/VBZ
#   of/IN
#   a/DT
#   cork/NN
#   core/NN
#   wound/NN
#   with/IN
#   string/VBG
#   then/RB
#   a/DT
#   leather/NN
#   cover/NN
#   stitched/VBN
#   on/IN
#   ,/,
#   and/CC
#   manufacture/NN
#   is/VBZ
#   regulated/VBN
#   by/IN
#   cricket/NN
#   law/NN
#   at/IN
#   first-class/JJ
#   level/NN
#   ./.
#   The/DT
#   trajectory/NN
#   of/IN
#   a/DT
#   cricket/NN
#   ball/NN
#   when/WRB
#   bowled/VBN
#   ,/,
#   through/IN
#   movement/NN
#   in/IN
#   the/DT
#   air/NN
#   ,/,
#   and/CC
#   off/IN
#   the/DT
#   ground/NN
#   ,/,
#   is/VBZ
#   influenced/VBN
#   by/IN
#   the/DT
#   action/NN
#   of/IN
#   the/DT
#   bowler/NN
#   and/CC
#   the/DT
#   condition/NN
#   of/IN
#   the/DT
#   ball/NN
#   and/CC
#   the/DT
#   pitch/NN
#   ,/,
#   while/IN
#   working/VBG
#   on/IN
#   the/DT
#   cricket/NN
#   ball/NN
#   to/TO
#   obtain/VB
#   optimum/JJ
#   condition/NN
#   is/VBZ
#   a/DT
#   key/JJ
#   role/NN
#   of/IN
#   the/DT
#   fielding/JJ
#   side/NN
#   ./.
#   The/DT
#   principal/JJ
#   method/NN
#   through/IN
#   which/WDT
#   the/DT
#   batsman/NN
#   scores/VBZ
#   runs/NNS
#   is/VBZ
#   by/IN
#   hitting/VBG
#   the/DT
#   ball/NN
#   ,/,
#   with/IN
#   the/DT
#   bat/NN
#   ,/,
#   into/IN
#   a/DT
#   position/NN
#   where/WRB
#   it/PRP
#   would/MD
#   be/VB
#   safe/JJ
#   to/TO
#   take/VB
#   a/DT
#   run/NN
#   ,/,
#   or/CC
#   by/IN
#   directing/VBG
#   the/DT
#   ball/NN
#   through/IN
#   or/CC
#   over/IN
#   the/DT
#   boundary/JJ
#   ./.
#   Cricket/NNP
#   balls/NNS
#   are/VBP
#   harder/JJR
#   and/CC
#   heavier/JJR
#   than/IN
#   baseballs/NNS
#   ./.
#   In/IN
#   day/NN
#   (PERSON Test/NNP)
#   cricket/NN
#   ,/,
#   professional/JJ
#   domestic/JJ
#   games/NNS
#   that/WDT
#   spread/VBP
#   over/IN
#   a/DT
#   multitude/NN
#   of/IN
#   days/NNS
#   ,/,
#   and/CC
#   almost/RB
#   the/DT
#   entirety/NN
#   of/IN
#   amateur/JJ
#   cricket/NN
#   ,/,
#   the/DT
#   traditional/JJ
#   red/JJ
#   cricket/NN
#   ball/NN
#   is/VBZ
#   normally/RB
#   used/VBN
#   ./.
#   In/IN
#   many/JJ
#   one/CD
#   day/NN
#   cricket/NN
#   matches/NNS
#   ,/,
#   a/DT
#   white/JJ
#   ball/NN
#   is/VBZ
#   used/VBN
#   instead/RB
#   in/IN
#   order/NN
#   to/TO
#   remain/VB
#   visible/JJ
#   under/IN
#   floodlights/NNS
#   ,/,
#   and/CC
#   since/IN
#   2010/CD
#   ,/,
#   pink/NN
#   has/VBZ
#   been/VBN
#   introduced/VBN
#   to/TO
#   contrast/VB
#   with/IN
#   players/NNS
#   '/POS
#   white/JJ
#   clothing/NN
#   and/CC
#   for/IN
#   improved/JJ
#   night/NN
#   visibility/NN
#   during/IN
#   day/night/JJ
#   Test/NNP
#   matches/NNS
#   ./.
#   Training/VBG
#   balls/NNS
#   of/IN
#   white/JJ
#   ,/,
#   red/JJ
#   and/CC
#   pink/NN
#   are/VBP
#   also/RB
#   common/JJ
#   ,/,
#   and/CC
#   tennis/NN
#   balls/NNS
#   and/CC
#   other/JJ
#   similar-sized/JJ
#   balls/NNS
#   can/MD
#   be/VB
#   used/VBN
#   for/IN
#   training/NN
#   or/CC
#   informal/JJ
#   cricket/NN
#   matches/NNS
#   ./.
#   During/IN
#   cricket/NN
#   matches/NNS
#   ,/,
#   the/DT
#   quality/NN
#   of/IN
#   the/DT
#   ball/NN
#   changes/NNS
#   to/TO
#   a/DT
#   point/NN
#   where/WRB
#   it/PRP
#   is/VBZ
#   no/RB
#   longer/RBR
#   usable/JJ
#   ,/,
#   and/CC
#   during/IN
#   this/DT
#   decline/NN
#   its/PRP$
#   properties/NNS
#   alter/NN
#   and/CC
#   thus/RB
#   can/MD
#   influence/VB
#   the/DT
#   match/NN
#   ./.
#   Altering/VBG
#   the/DT
#   state/NN
#   of/IN
#   the/DT
#   cricket/NN
#   ball/NN
#   outside/IN
#   the/DT
#   permitted/JJ
#   manners/NNS
#   designated/VBN
#   in/IN
#   the/DT
#   rules/NNS
#   of/IN
#   cricket/NN
#   is/VBZ
#   prohibited/VBN
#   during/IN
#   a/DT
#   match/NN
#   ,/,
#   and/CC
#   so-called/JJ
#   ``/``
#   ball/NN
#   tampering/NN
#   ''/''
#   has/VBZ
#   resulted/VBN
#   in/IN
#   numerous/JJ
#   controversies/NNS
#   ./.
#   Injuries/NNS
#   and/CC
#   fatalities/NNS
#   have/VBP
#   been/VBN
#   caused/VBN
#   by/IN
#   cricket/NN
#   balls/NNS
#   during/IN
#   matches/NNS
#   ./.
#   The/DT
#   hazards/NNS
#   posed/VBN
#   by/IN
#   cricket/NN
#   balls/NNS
#   were/VBD
#   a/DT
#   key/JJ
#   motivator/NN
#   for/IN
#   the/DT
#   introduction/NN
#   of/IN
#   protective/JJ
#   equipment/NN
#   ./.
#   (GPE British/JJ)
#   (ORGANIZATION Standard/NNP)
#   BS/NNP
#   5993/CD
#   specifies/VBZ
#   the/DT
#   construction/NN
#   details/NNS
#   ,/,
#   dimensions/NNS
#   ,/,
#   quality/NN
#   and/CC
#   performance/NN
#   of/IN
#   cricket/NN
#   balls/NNS
#   ./.
#   A/DT
#   cricket/NN
#   ball/NN
#   is/VBZ
#   made/VBN
#   with/IN
#   a/DT
#   core/NN
#   of/IN
#   cork/NN
#   ,/,
#   which/WDT
#   is/VBZ
#   layered/VBN
#   with/IN
#   tightly/RB
#   wound/IN
#   string/NN
#   ,/,
#   and/CC
#   covered/VBN
#   by/IN
#   a/DT
#   leather/NN
#   case/NN
#   with/IN
#   a/DT
#   slightly/RB
#   raised/VBN
#   sewn/NN
#   seam/NN
#   ./.
#   In/IN
#   a/DT
#   top-quality/NN
#   ball/NN
#   suitable/JJ
#   for/IN
#   the/DT
#   highest/JJS
#   levels/NNS
#   of/IN
#   competition/NN
#   ,/,
#   the/DT
#   covering/NN
#   is/VBZ
#   constructed/VBN
#   of/IN
#   four/CD
#   pieces/NNS
#   of/IN
#   leather/NN
#   shaped/VBD
#   similar/JJ
#   to/TO
#   the/DT
#   peel/NN
#   of/IN
#   a/DT
#   quartered/JJ
#   orange/NN
#   ,/,
#   but/CC
#   one/CD
#   hemisphere/NN
#   is/VBZ
#   rotated/VBN
#   by/IN
#   90/CD
#   degrees/NNS
#   with/IN
#   respect/NN
#   to/TO
#   the/DT
#   other/JJ
#   ./.
#   The/DT
#   ``/``
#   equator/NN
#   ''/''
#   of/IN
#   the/DT
#   ball/NN
#   is/VBZ
#   stitched/VBN
#   with/IN
#   string/NN
#   to/TO
#   form/VB
#   the/DT
#   ball/NN
#   's/POS
#   prominent/JJ
#   seam/NN
#   ,/,
#   with/IN
#   six/CD
#   rows/NNS
#   of/IN
#   stitches/NNS
#   ./.
#   The/DT
#   remaining/VBG
#   two/CD
#   joins/NNS
#   between/IN
#   the/DT
#   leather/NN
#   pieces/NNS
#   are/VBP
#   stitched/VBN
#   internally/RB
#   forming/VBG
#   the/DT
#   quarter/NN
#   seam/NN
#   ./.
#   Lower-quality/NNP
#   balls/NNS
#   with/IN
#   a/DT
#   two-piece/JJ
#   covering/NN
#   are/VBP
#   also/RB
#   popular/JJ
#   for/IN
#   practice/NN
#   and/CC
#   lower-level/JJ
#   competition/NN
#   due/JJ
#   to/TO
#   their/PRP$
#   lower/JJR
#   cost/NN
#   ./.
#   The/DT
#   nature/NN
#   of/IN
#   the/DT
#   cricket/NN
#   ball/NN
#   slightly/RB
#   varies/VBZ
#   with/IN
#   its/PRP$
#   manufacturer/NN
#   ./.
#   (FACILITY White/NNP Kookaburra/NNP)
#   balls/NNS
#   are/VBP
#   used/VBN
#   in/IN
#   one-day/JJ
#   and/CC
#   (ORGANIZATION Twenty20/NNP)
#   international/JJ
#   matches/NNS
#   ,/,
#   while/IN
#   red/JJ
#   Kookaburras/NNP
#   are/VBP
#   used/VBN
#   in/IN
#   test/NN
#   matches/NNS
#   played/VBN
#   in/IN
#   most/JJS
#   of/IN
#   the/DT
#   ten/JJ
#   test-playing/JJ
#   nations/NNS
#   ,/,
#   except/IN
#   for/IN
#   the/DT
#   (LOCATION West/NNP)
#   Indies/NNPS
#   and/CC
#   (GPE England/NNP)
#   ,/,
#   who/WP
#   use/VBP
#   (PERSON Dukes/NNP)
#   ,/,
#   and/CC
#   (GPE India/NNP)
#   ,/,
#   who/WP
#   use/VBP
#   SG/NNP
#   balls/NNS
#   ./.
#   Cricket/NNP
#   balls/NNS
#   are/VBP
#   traditionally/RB
#   red/JJ
#   ,/,
#   and/CC
#   red/JJ
#   balls/NNS
#   are/VBP
#   used/VBN
#   in/IN
#   (GPE Test/NNP)
#   cricket/NN
#   and/CC
#   First-class/NNP
#   cricket/NN
#   but/CC
#   proposals/NNS
#   to/TO
#   introduce/VB
#   other/JJ
#   colours/NN
#   date/NN
#   back/RB
#   at/IN
#   least/JJS
#   as/RB
#   early/RB
#   as/IN
#   1937/CD
#   ./.
#   White/NNP
#   balls/NNS
#   were/VBD
#   introduced/VBN
#   when/WRB
#   one-day/JJ
#   matches/NNS
#   began/VBD
#   being/VBG
#   played/VBN
#   at/IN
#   night/NN
#   under/IN
#   floodlights/NNS
#   ,/,
#   as/IN
#   they/PRP
#   are/VBP
#   more/RBR
#   visible/JJ
#   at/IN
#   night/NN
#   ;/:
#   all/DT
#   professional/JJ
#   one-day/JJ
#   matches/NNS
#   are/VBP
#   now/RB
#   played/VBN
#   with/IN
#   white/JJ
#   balls/NNS
#   ,/,
#   even/RB
#   when/WRB
#   they/PRP
#   are/VBP
#   not/RB
#   played/VBN
#   at/IN
#   night/NN
#   ./.
#   The/DT
#   white/JJ
#   balls/NNS
#   have/VBP
#   been/VBN
#   found/VBN
#   to/TO
#   behave/VB
#   differently/RB
#   from/IN
#   the/DT
#   red/JJ
#   balls/NNS
#   :/:
#   most/JJS
#   notably/RB
#   ,/,
#   they/PRP
#   swing/VBP
#   a/DT
#   lot/NN
#   more/RBR
#   during/IN
#   the/DT
#   first/JJ
#   half/NN
#   of/IN
#   an/DT
#   innings/NN
#   than/IN
#   the/DT
#   red/JJ
#   balls/NNS
#   ,/,
#   and/CC
#   they/PRP
#   deteriorate/VBP
#   more/RBR
#   quickly/RB
#   ./.
#   Manufacturers/NNS
#   claim/VBP
#   that/IN
#   white/JJ
#   and/CC
#   red/JJ
#   balls/NNS
#   are/VBP
#   manufactured/VBN
#   using/VBG
#   the/DT
#   same/JJ
#   methods/NNS
#   and/CC
#   materials/NNS
#   ,/,
#   other/JJ
#   than/IN
#   the/DT
#   dyeing/NN
#   of/IN
#   the/DT
#   leather/NN
#   ./.
#   Another/DT
#   problem/NN
#   associated/VBN
#   with/IN
#   white/JJ
#   cricket/NN
#   balls/NNS
#   used/VBN
#   in/IN
#   One/CD
#   Day/NNP
#   Internationals/NNP
#   is/VBZ
#   that/IN
#   they/PRP
#   quickly/RB
#   become/VBP
#   dirty/JJ
#   or/CC
#   dull/JJ
#   in/IN
#   colour/NN
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   more/RBR
#   difficult/JJ
#   for/IN
#   batsmen/NNS
#   to/TO
#   sight/VB
#   the/DT
#   ball/NN
#   after/IN
#   30-40/JJ
#   overs/NNS
#   of/IN
#   use/NN
#   ./.
#   Since/IN
#   October/NNP
#   2012/CD
#   ,/,
#   this/DT
#   has/VBZ
#   been/VBN
#   managed/VBN
#   by/IN
#   the/DT
#   use/NN
#   of/IN
#   two/CD
#   new/JJ
#   white/JJ
#   balls/NNS
#   in/IN
#   each/DT
#   innings/NNS
#   ,/,
#   with/IN
#   a/DT
#   different/JJ
#   ball/NN
#   used/VBN
#   from/IN
#   each/DT
#   bowling/VBG
#   end/NN
#   ;/:
#   the/DT
#   same/JJ
#   strategy/NN
#   was/VBD
#   used/VBN
#   in/IN
#   the/DT
#   1992/CD
#   and/CC
#   1996/CD
#   Cricket/NNP
#   World/NNP
#   Cups/NNP
#   ./.
#   (PERSON Between/NNP)
#   October/NNP
#   2007/CD
#   and/CC
#   October/NNP
#   2012/CD
#   ,/,
#   the/DT
#   issue/NN
#   had/VBD
#   been/VBN
#   managed/VBN
#   using/VBG
#   one/CD
#   new/JJ
#   ball/NN
#   from/IN
#   the/DT
#   start/NN
#   of/IN
#   the/DT
#   innings/NNS
#   ,/,
#   then/RB
#   swapping/VBG
#   it/PRP
#   at/IN
#   the/DT
#   end/NN
#   of/IN
#   the/DT
#   34th/CD
#   over/IN
#   with/IN
#   a/DT
#   ``/``
#   reconditioned/JJ
#   ball/NN
#   ''/''
#   ,/,
#   which/WDT
#   was/VBD
#   neither/DT
#   new/JJ
#   nor/CC
#   too/RB
#   dirty/JJ
#   to/TO
#   see/VB
#   ./.
#   Before/IN
#   October/NNP
#   2007/CD
#   ,/,
#   except/IN
#   during/IN
#   1992/CD
#   and/CC
#   1996/CD
#   World/NNP
#   Cups/NNP
#   ,/,
#   only/RB
#   one/CD
#   ball/NN
#   was/VBD
#   used/VBN
#   during/IN
#   an/DT
#   innings/NN
#   of/IN
#   an/DT
#   (ORGANIZATION ODI/NNP)
#   and/CC
#   it/PRP
#   was/VBD
#   at/IN
#   the/DT
#   umpires/NNS
#   '/POS
#   discretion/NN
#   to/TO
#   change/VB
#   the/DT
#   ball/NN
#   if/IN
#   it/PRP
#   was/VBD
#   difficult/JJ
#   to/TO
#   see/VB
#   ./.
#   Pink/VB
#   balls/NNS
#   were/VBD
#   developed/VBN
#   in/IN
#   the/DT
#   2000s/CD
#   to/TO
#   enable/VB
#   Tests/NNS
#   and/CC
#   first-class/NN
#   matches/NNS
#   played/VBD
#   at/IN
#   night/NN
#   ./.
#   The/DT
#   red/JJ
#   ball/NN
#   is/VBZ
#   unsuited/VBN
#   to/TO
#   night/NN
#   tests/NNS
#   due/JJ
#   to/TO
#   poor/JJ
#   visibility/NN
#   ,/,
#   and/CC
#   the/DT
#   white/JJ
#   ball/NN
#   is/VBZ
#   unsuited/VBN
#   to/TO
#   first-class/NN
#   cricket/NN
#   because/IN
#   it/PRP
#   deteriorates/VBZ
#   rapidly/RB
#   and/CC
#   can/MD
#   not/RB
#   be/VB
#   used/VBN
#   for/IN
#   eighty/JJ
#   overs/NNS
#   as/IN
#   specified/VBN
#   in/IN
#   the/DT
#   rules/NNS
#   ,/,
#   so/IN
#   the/DT
#   pink/NN
#   ball/NN
#   was/VBD
#   designed/VBN
#   to/TO
#   provide/VB
#   a/DT
#   satisfactory/JJ
#   compromise/NN
#   on/IN
#   both/DT
#   issues/NNS
#   ./.
#   It/PRP
#   is/VBZ
#   still/RB
#   considered/VBN
#   more/RBR
#   difficult/JJ
#   to/TO
#   see/VB
#   than/IN
#   a/DT
#   white/JJ
#   ball/NN
#   ;/:
#   and/CC
#   the/DT
#   leather/NN
#   is/VBZ
#   more/RBR
#   heavily/RB
#   dyed/VBN
#   than/IN
#   a/DT
#   red/JJ
#   ball/NN
#   ,/,
#   which/WDT
#   better/RBR
#   preserves/VBZ
#   its/PRP$
#   colour/NN
#   and/CC
#   visibility/NN
#   as/IN
#   it/PRP
#   wears/VBZ
#   but/CC
#   also/RB
#   gives/VBZ
#   it/PRP
#   slightly/RB
#   different/JJ
#   wear/NN
#   characteristics/NNS
#   ./.
#   It/PRP
#   has/VBZ
#   performed/VBN
#   well/RB
#   enough/RB
#   in/IN
#   testing/VBG
#   and/CC
#   first-class/JJ
#   cricket/NN
#   to/TO
#   be/VB
#   approved/VBN
#   for/IN
#   use/NN
#   in/IN
#   international/JJ
#   cricket/NN
#   ./.
#   A/DT
#   pink/NN
#   ball/NN
#   was/VBD
#   used/VBN
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   in/IN
#   an/DT
#   international/JJ
#   match/NN
#   in/IN
#   July/NNP
#   2009/CD
#   when/WRB
#   the/DT
#   (ORGANIZATION England/NNP Women/NNP)
#   's/POS
#   team/NN
#   defeated/VBD
#   (GPE Australia/NNP)
#   in/IN
#   a/DT
#   one-day/JJ
#   match/NN
#   at/IN
#   (ORGANIZATION Wormsley/NNP)
#   ,/,
#   and/CC
#   a/DT
#   pink/NN
#   ball/NN
#   was/VBD
#   used/VBN
#   in/IN
#   a/DT
#   day-night/JJ
#   Test/NNP
#   match/NN
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   in/IN
#   November/NNP
#   2015/CD
#   ./.
#   Other/JJ
#   colours/NNS
#   were/VBD
#   also/RB
#   experimented/VBN
#   with/IN
#   ,/,
#   such/JJ
#   as/IN
#   yellow/JJ
#   and/CC
#   orange/NN
#   (/(
#   glowing/VBG
#   composite/NN
#   )/)
#   ,/,
#   for/IN
#   improved/VBN
#   night/NN
#   visibility/NN
#   ,/,
#   but/CC
#   pink/VBP
#   proved/VBN
#   to/TO
#   be/VB
#   the/DT
#   preferred/JJ
#   option/NN
#   ./.
#   As/IN
#   of/IN
#   2014/CD
#   ,/,
#   the/DT
#   ball/NN
#   used/VBN
#   in/IN
#   (GPE Test/NNP)
#   match/NN
#   cricket/NN
#   in/IN
#   (GPE England/NNP)
#   had/VBD
#   a/DT
#   UK/NNP
#   recommended/VBD
#   retail/JJ
#   price/NN
#   of/IN
#   £100/NN
#   ./.
#   In/IN
#   test/NN
#   match/NN
#   cricket/NN
#   this/DT
#   ball/NN
#   is/VBZ
#   used/VBN
#   for/IN
#   a/DT
#   minimum/NN
#   of/IN
#   80/CD
#   overs/NNS
#   (/(
#   theoretically/RB
#   five/CD
#   hours/NNS
#   and/CC
#   twenty/JJ
#   minutes/NNS
#   of/IN
#   play/NN
#   )/)
#   ,/,
#   after/IN
#   which/WDT
#   the/DT
#   fielding/NN
#   side/NN
#   has/VBZ
#   the/DT
#   option/NN
#   of/IN
#   using/VBG
#   a/DT
#   new/JJ
#   ball/NN
#   ./.
#   In/IN
#   professional/JJ
#   one/CD
#   day/NN
#   cricket/NN
#   ,/,
#   at/IN
#   least/JJS
#   two/CD
#   new/JJ
#   balls/NNS
#   are/VBP
#   used/VBN
#   for/IN
#   each/DT
#   match/NN
#   ./.
#   Amateur/JJ
#   cricketers/NNS
#   often/RB
#   have/VBP
#   to/TO
#   use/VB
#   old/JJ
#   balls/NNS
#   ,/,
#   or/CC
#   cheap/JJ
#   substitutes/NNS
#   ,/,
#   in/IN
#   which/WDT
#   case/NN
#   the/DT
#   changes/NNS
#   in/IN
#   the/DT
#   condition/NN
#   of/IN
#   the/DT
#   ball/NN
#   may/MD
#   be/VB
#   different/JJ
#   from/IN
#   professional/JJ
#   cricket/NN
#   ./.
#   There/EX
#   are/VBP
#   three/CD
#   main/JJ
#   manufacturers/NNS
#   of/IN
#   cricket/NN
#   balls/NNS
#   used/VBN
#   in/IN
#   international/JJ
#   matches/NNS
#   :/:
#   Kookaburra/NNP
#   ,/,
#   (PERSON Dukes/NNP)
#   and/CC
#   (ORGANIZATION SG/NNP)
#   ./.
#   The/DT
#   manufacturer/NN
#   of/IN
#   the/DT
#   red/JJ
#   (/(
#   or/CC
#   pink/VB
#   )/)
#   balls/NNS
#   used/VBN
#   for/IN
#   Tests/NNS
#   varies/NNS
#   depending/VBG
#   on/IN
#   location/NN
#   :/:
#   (GPE India/NNP)
#   uses/VBZ
#   (ORGANIZATION SG/NNP)
#   ;/:
#   (GPE England/NNP)
#   ,/,
#   (GPE Ireland/NNP)
#   and/CC
#   the/DT
#   (LOCATION West/NNP)
#   Indies/NNPS
#   use/VBP
#   (GPE Dukes/NNP)
#   ;/:
#   and/CC
#   all/DT
#   other/JJ
#   countries/NNS
#   use/VBP
#   (PERSON Kookaburra/NNP)
#   ./.
#   The/DT
#   different/JJ
#   manufacturers/NNS
#   '/POS
#   balls/NNS
#   behave/VBP
#   differently/RB
#   :/:
#   for/IN
#   instance/NN
#   Dukes/NNP
#   balls/NNS
#   have/VBP
#   a/DT
#   prouder/NN
#   seam/NN
#   and/CC
#   will/MD
#   tend/VB
#   to/TO
#   swing/VBG
#   more/JJR
#   than/IN
#   (ORGANIZATION Kookaburra/NNP)
#   balls/NNS
#   –/VBP
#   providing/VBG
#   a/DT
#   home/NN
#   advantage/NN
#   when/WRB
#   playing/VBG
#   against/IN
#   a/DT
#   team/NN
#   unfamiliar/NN
#   with/IN
#   the/DT
#   ball/NN
#   ./.
#   All/DT
#   limited/JJ
#   overs/NNS
#   international/JJ
#   matches/NNS
#   ,/,
#   regardless/RB
#   of/IN
#   location/NN
#   ,/,
#   are/VBP
#   played/VBN
#   with/IN
#   white/JJ
#   Kookaburra/NNP
#   balls/NNS
#   ./.
#   (FACILITY White/NNP Dukes/NNP)
#   balls/NNS
#   were/VBD
#   used/VBN
#   at/IN
#   the/DT
#   1999/CD
#   Cricket/NNP
#   World/NNP
#   Cup/NNP
#   ,/,
#   but/CC
#   the/DT
#   ball/NN
#   behaved/VBD
#   more/RBR
#   erratically/RB
#   than/IN
#   the/DT
#   (ORGANIZATION Kookaburra/NNP)
#   and/CC
#   white/JJ
#   Dukes/NNS
#   have/VBP
#   not/RB
#   been/VBN
#   used/VBN
#   since/IN
#   ./.
#   Domestic/JJ
#   competitions/NNS
#   may/MD
#   use/VB
#   a/DT
#   domestic/JJ
#   manufacturer/NN
#   :/:
#   for/IN
#   example/NN
#   ,/,
#   (GPE Pakistan/NNP)
#   uses/VBZ
#   (GPE Grays/NNP)
#   balls/NNS
#   in/IN
#   its/PRP$
#   first-class/JJ
#   competitions/NNS
#   ./.
#   Cricket/NNP
#   balls/NNS
#   can/MD
#   be/VB
#   bowled/VBN
#   at/IN
#   close/RB
#   to/TO
#   160/CD
#   km/h/NNS
#   (/(
#   100/CD
#   mph/NN
#   )/)
#   by/IN
#   pace/NN
#   bowlers/NNS
#   and/CC
#   made/VBD
#   to/TO
#   deviate/VB
#   from/IN
#   a/DT
#   straight/JJ
#   course/NN
#   ,/,
#   both/DT
#   in/IN
#   the/DT
#   air/NN
#   (/(
#   known/VBN
#   as/IN
#   'swinging/VBG
#   '/''
#   )/)
#   and/CC
#   off/IN
#   the/DT
#   ground/NN
#   (/(
#   known/VBN
#   as/IN
#   'seaming/VBG
#   '/''
#   )/)
#   ./.
#   A/DT
#   spin/JJ
#   bowler/NN
#   imparts/NNS
#   lateral/JJ
#   revolutions/NNS
#   on/IN
#   the/DT
#   ball/NN
#   at/IN
#   the/DT
#   point/NN
#   of/IN
#   delivery/NN
#   ,/,
#   so/IN
#   that/IN
#   when/WRB
#   it/PRP
#   bounces/VBZ
#   it/PRP
#   deviates/VBZ
#   from/IN
#   a/DT
#   straight/JJ
#   course/NN
#   ./.
#   As/IN
#   cricket/NN
#   bats/NNS
#   have/VBP
#   become/VBN
#   thicker/NN
#   ,/,
#   the/DT
#   ball/NN
#   can/MD
#   now/RB
#   be/VB
#   hit/VBN
#   well/RB
#   over/IN
#   100/CD
#   metres/NNS
#   before/IN
#   touching/VBG
#   the/DT
#   ground/NN
#   ./.
#   (PERSON Cricket/NNP)
#   commentator/NN
#   and/CC
#   former/JJ
#   (GPE Test/NNP)
#   bowler/NN
#   (PERSON Simon/NNP Doull/NNP)
#   noted/VBD
#   that/IN
#   cricket/NN
#   balls/NNS
#   produced/VBN
#   after/IN
#   (PERSON Cricket/NNP)
#   World/NNP
#   Cup/NNP
#   2015/CD
#   produced/VBD
#   a/DT
#   lot/NN
#   less/JJR
#   swing/VBG
#   regardless/NN
#   of/IN
#   manufacturer/NN
#   ./.
#   This/DT
#   was/VBD
#   said/VBD
#   to/TO
#   be/VB
#   apparent/JJ
#   in/IN
#   2017/CD
#   (ORGANIZATION ICC/NNP)
#   Champions/NNP
#   Trophy/NNP
#   ,/,
#   even/RB
#   on/IN
#   traditionally/RB
#   swing-friendly/JJ
#   (GPE British/JJ)
#   pitches/NNS
#   ,/,
#   particularly/RB
#   with/IN
#   white/JJ
#   balls/NNS
#   ,/,
#   but/CC
#   the/DT
#   former/JJ
#   (LOCATION West/NNP Indian/NNP)
#   bowler/NN
#   (PERSON Ian/NNP Bishop/NNP)
#   was/VBD
#   unwilling/VBG
#   to/TO
#   support/VB
#   this/DT
#   ./.
#   In/IN
#   (GPE Test/NNP)
#   cricket/NN
#   ,/,
#   a/DT
#   new/JJ
#   ball/NN
#   is/VBZ
#   used/VBN
#   at/IN
#   the/DT
#   start/NN
#   of/IN
#   each/DT
#   innings/NNS
#   in/IN
#   a/DT
#   match/NN
#   ./.
#   In/IN
#   (GPE Limited/NNP)
#   Over/NNP
#   Internationals/NNP
#   ,/,
#   two/CD
#   new/JJ
#   balls/NNS
#   ,/,
#   one/CD
#   from/IN
#   each/DT
#   end/NN
#   ,/,
#   are/VBP
#   used/VBN
#   at/IN
#   the/DT
#   start/NN
#   of/IN
#   each/DT
#   innings/NNS
#   ./.
#   A/DT
#   cricket/NN
#   ball/NN
#   may/MD
#   not/RB
#   be/VB
#   replaced/VBN
#   except/IN
#   under/IN
#   specific/JJ
#   conditions/NNS
#   described/VBN
#   in/IN
#   the/DT
#   (ORGANIZATION Laws/NNP)
#   of/IN
#   (GPE Cricket/NNP)
#   :/:
#   The/DT
#   ball/NN
#   is/VBZ
#   not/RB
#   replaced/VBN
#   if/IN
#   it/PRP
#   is/VBZ
#   hit/VBN
#   into/IN
#   the/DT
#   crowd/NN
#   -/:
#   the/DT
#   crowd/NN
#   must/MD
#   return/VB
#   it/PRP
#   ./.
#   If/IN
#   the/DT
#   ball/NN
#   is/VBZ
#   damaged/VBN
#   ,/,
#   lost/VBN
#   ,/,
#   or/CC
#   illegally/RB
#   modified/VBN
#   ,/,
#   it/PRP
#   will/MD
#   be/VB
#   replaced/VBN
#   by/IN
#   a/DT
#   used/JJ
#   ball/NN
#   in/IN
#   similar/JJ
#   condition/NN
#   to/TO
#   the/DT
#   replaced/VBN
#   ball/NN
#   ./.
#   A/DT
#   new/JJ
#   ball/NN
#   can/MD
#   only/RB
#   be/VB
#   used/VBN
#   after/IN
#   the/DT
#   specified/JJ
#   minimum/JJ
#   number/NN
#   of/IN
#   overs/NNS
#   have/VBP
#   been/VBN
#   bowled/VBN
#   with/IN
#   the/DT
#   old/JJ
#   one/NN
#   ./.
#   Because/IN
#   a/DT
#   single/JJ
#   ball/NN
#   is/VBZ
#   used/VBN
#   for/IN
#   an/DT
#   extended/JJ
#   period/NN
#   of/IN
#   play/NN
#   ,/,
#   its/PRP$
#   surface/NN
#   wears/NNS
#   down/RB
#   and/CC
#   becomes/VBZ
#   rough/JJ
#   ./.
#   The/DT
#   bowlers/NNS
#   may/MD
#   polish/VB
#   it/PRP
#   whenever/WRB
#   they/PRP
#   can/MD
#   ,/,
#   usually/RB
#   by/IN
#   rubbing/VBG
#   it/PRP
#   on/IN
#   their/PRP$
#   trousers/NNS
#   ,/,
#   producing/VBG
#   the/DT
#   characteristic/JJ
#   red/JJ
#   stain/NN
#   that/WDT
#   can/MD
#   often/RB
#   be/VB
#   seen/VBN
#   there/RB
#   ./.
#   However/RB
#   ,/,
#   they/PRP
#   will/MD
#   usually/RB
#   only/RB
#   polish/JJ
#   one/CD
#   side/NN
#   of/IN
#   the/DT
#   ball/NN
#   ,/,
#   in/IN
#   order/NN
#   to/TO
#   create/VB
#   'swing/VBG
#   '/''
#   as/IN
#   it/PRP
#   travels/VBZ
#   through/IN
#   the/DT
#   air/NN
#   ./.
#   They/PRP
#   may/MD
#   apply/VB
#   saliva/NN
#   or/CC
#   sweat/NN
#   to/TO
#   the/DT
#   ball/NN
#   as/IN
#   they/PRP
#   polish/VBP
#   it/PRP
#   ./.
#   The/DT
#   seam/NN
#   of/IN
#   a/DT
#   cricket/NN
#   ball/NN
#   can/MD
#   also/RB
#   be/VB
#   used/VBN
#   to/TO
#   produce/VB
#   different/JJ
#   trajectories/NNS
#   through/IN
#   the/DT
#   air/NN
#   ,/,
#   with/IN
#   the/DT
#   technique/NN
#   known/VBN
#   as/IN
#   swing/VBG
#   bowling/NN
#   ,/,
#   or/CC
#   to/TO
#   produce/VB
#   sideways/JJ
#   movement/NN
#   as/IN
#   it/PRP
#   bounces/VBZ
#   off/IN
#   the/DT
#   pitch/NN
#   ,/,
#   with/IN
#   the/DT
#   technique/NN
#   known/VBN
#   as/IN
#   seam/NN
#   bowling/NN
#   ./.
#   Since/IN
#   the/DT
#   condition/NN
#   of/IN
#   the/DT
#   cricket/NN
#   ball/NN
#   is/VBZ
#   crucial/JJ
#   to/TO
#   the/DT
#   amount/NN
#   of/IN
#   movement/NN
#   through/IN
#   the/DT
#   air/NN
#   a/DT
#   bowler/NN
#   can/MD
#   produce/VB
#   ,/,
#   the/DT
#   laws/NNS
#   governing/VBG
#   what/WP
#   players/NNS
#   may/MD
#   and/CC
#   may/MD
#   not/RB
#   do/VB
#   to/TO
#   the/DT
#   ball/NN
#   are/VBP
#   specific/JJ
#   and/CC
#   rigorously/RB
#   enforced/VBN
#   ./.
#   The/DT
#   umpires/NNS
#   will/MD
#   inspect/VB
#   the/DT
#   ball/NN
#   frequently/RB
#   during/IN
#   a/DT
#   match/NN
#   ./.
#   If/IN
#   the/DT
#   ball/NN
#   is/VBZ
#   out/IN
#   of/IN
#   shape/NN
#   due/JJ
#   to/TO
#   normal/JJ
#   wear/NN
#   and/CC
#   tear/VB
#   due/JJ
#   to/TO
#   batting/VBG
#   and/CC
#   ball/VB
#   hitting/VBG
#   the/DT
#   pitch/NN
#   ,/,
#   a/DT
#   ball/NN
#   of/IN
#   similar/JJ
#   usage/NN
#   rate/NN
#   and/CC
#   condition/NN
#   will/MD
#   be/VB
#   replaced/VBN
#   :/:
#   e.g/NN
#   ./.
#   a/DT
#   ball/NN
#   about/IN
#   30/CD
#   overs/NNS
#   old/JJ
#   will/MD
#   be/VB
#   replaced/VBN
#   by/IN
#   a/DT
#   ball/NN
#   about/IN
#   the/DT
#   same/JJ
#   age/NN
#   ./.
#   It/PRP
#   is/VBZ
#   illegal/JJ
#   for/IN
#   a/DT
#   player/NN
#   to/TO
#   :/:
#   Despite/IN
#   these/DT
#   rules/NNS
#   ,/,
#   it/PRP
#   can/MD
#   be/VB
#   tempting/VBG
#   for/IN
#   players/NNS
#   to/TO
#   gain/VB
#   an/DT
#   advantage/NN
#   by/IN
#   breaking/VBG
#   them/PRP
#   ./.
#   There/EX
#   have/VBP
#   been/VBN
#   a/DT
#   handful/NN
#   of/IN
#   incidents/NNS
#   of/IN
#   so-called/JJ
#   ball/NN
#   tampering/NN
#   at/IN
#   the/DT
#   highest/JJS
#   levels/NNS
#   of/IN
#   cricket/NN
#   ./.
#   A/DT
#   new/JJ
#   cricket/NN
#   ball/NN
#   is/VBZ
#   harder/JJR
#   than/IN
#   a/DT
#   worn/JJ
#   one/CD
#   ,/,
#   and/CC
#   is/VBZ
#   preferred/VBN
#   by/IN
#   fast/NN
#   bowlers/NNS
#   because/IN
#   of/IN
#   the/DT
#   speed/NN
#   and/CC
#   bounce/NN
#   of/IN
#   the/DT
#   ball/NN
#   off/IN
#   the/DT
#   pitch/NN
#   ./.
#   Older/JJR
#   balls/NNS
#   tend/VBP
#   to/TO
#   spin/VB
#   more/JJR
#   as/IN
#   the/DT
#   roughness/NN
#   grips/VBZ
#   the/DT
#   pitch/NN
#   more/RBR
#   when/WRB
#   the/DT
#   ball/NN
#   bounces/NNS
#   ,/,
#   so/RB
#   spin/JJ
#   bowlers/NNS
#   prefer/VBP
#   to/TO
#   use/VB
#   a/DT
#   worn/JJ
#   ball/NN
#   ,/,
#   though/IN
#   a/DT
#   ball/NN
#   of/IN
#   about/IN
#   8–10/CD
#   overs/NNS
#   old/JJ
#   is/VBZ
#   still/RB
#   useful/JJ
#   to/TO
#   a/DT
#   spinner/NN
#   as/IN
#   it/PRP
#   can/MD
#   get/VB
#   more/JJR
#   drift/NN
#   in/IN
#   the/DT
#   air/NN
#   ./.
#   Uneven/VBN
#   wear/VBP
#   on/IN
#   older/JJR
#   balls/NNS
#   may/MD
#   also/RB
#   make/VB
#   reverse/NN
#   swing/VBG
#   possible/JJ
#   ./.
#   A/DT
#   captain/NN
#   may/MD
#   delay/VB
#   the/DT
#   request/NN
#   for/IN
#   a/DT
#   new/JJ
#   ball/NN
#   if/IN
#   she/he/JJ
#   prefers/NNS
#   to/TO
#   have/VB
#   spin/NN
#   bowlers/NNS
#   operating/VBG
#   ,/,
#   but/CC
#   usually/RB
#   asks/VBZ
#   for/IN
#   the/DT
#   new/JJ
#   ball/NN
#   soon/RB
#   after/IN
#   it/PRP
#   becomes/VBZ
#   available/JJ
#   ./.
#   Cricket/NNP
#   balls/NNS
#   are/VBP
#   hard/JJ
#   and/CC
#   potentially/RB
#   lethal/JJ
#   ,/,
#   so/RB
#   most/JJS
#   of/IN
#   today/NN
#   's/POS
#   batsmen/NNS
#   and/CC
#   close/JJ
#   fielders/NNS
#   often/RB
#   wear/VBP
#   protective/JJ
#   equipment/NN
#   ./.
#   (PERSON Cricket/NNP)
#   ball/NN
#   injuries/NNS
#   are/VBP
#   fairly/RB
#   frequent/JJ
#   ,/,
#   including/VBG
#   eye/NN
#   (/(
#   with/IN
#   some/DT
#   players/NNS
#   having/VBG
#   lost/VBN
#   eyes/NNS
#   )/)
#   ,/,
#   head/NN
#   and/CC
#   face/NN
#   ,/,
#   finger/NN
#   and/CC
#   toe/NN
#   ,/,
#   teeth/NNS
#   and/CC
#   testicular/JJ
#   injuries/NNS
#   ./.
#   (PERSON Frederick/NNP)
#   ,/,
#   (GPE Prince/NNP)
#   of/IN
#   (GPE Wales/NNP)
#   (/(
#   1707–1751/CD
#   )/)
#   is/VBZ
#   often/RB
#   said/VBD
#   to/TO
#   have/VB
#   died/VBN
#   of/IN
#   complications/NNS
#   after/IN
#   being/VBG
#   hit/VBN
#   by/IN
#   a/DT
#   cricket/NN
#   ball/NN
#   ,/,
#   although/IN
#   the/DT
#   connection/NN
#   between/IN
#   the/DT
#   incident/NN
#   and/CC
#   his/PRP$
#   actual/JJ
#   cause/NN
#   of/IN
#   death/NN
#   is/VBZ
#   unproven/JJ
#   ./.
#   Glamorgan/NNP
#   player/NN
#   (PERSON Roger/NNP Davis/NNP)
#   was/VBD
#   seriously/RB
#   injured/VBN
#   by/IN
#   a/DT
#   ball/NN
#   in/IN
#   1971/CD
#   when/WRB
#   he/PRP
#   was/VBD
#   hit/VBN
#   on/IN
#   the/DT
#   head/NN
#   while/IN
#   fielding/VBG
#   ./.
#   The/DT
#   (GPE Indian/JJ)
#   batsman/NN
#   (PERSON Nariman/NNP)
#   'Nari/NNP
#   '/POS
#   (PERSON Contractor/NNP)
#   had/VBD
#   to/TO
#   retire/VB
#   from/IN
#   the/DT
#   game/NN
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   the/DT
#   head/NN
#   by/IN
#   a/DT
#   ball/NN
#   in/IN
#   the/DT
#   (LOCATION West/NNP)
#   Indies/NNPS
#   in/IN
#   1962/CD
#   ./.
#   In/IN
#   1998/CD
#   ,/,
#   (GPE Indian/JJ)
#   cricketer/NN
#   (PERSON Raman/NNP Lamba/NNP)
#   died/VBD
#   when/WRB
#   a/DT
#   cricket/NN
#   ball/NN
#   hit/VBD
#   his/PRP$
#   head/NN
#   in/IN
#   a/DT
#   club/NN
#   match/NN
#   in/IN
#   (GPE Dhaka/NNP)
#   ./.
#   (PERSON Lamba/NNP)
#   was/VBD
#   fielding/VBG
#   at/IN
#   forward/RB
#   short/JJ
#   leg/NN
#   without/IN
#   a/DT
#   helmet/NN
#   when/WRB
#   a/DT
#   ball/NN
#   struck/VBN
#   by/IN
#   batsman/NN
#   (PERSON Mehrab/NNP Hossain/NNP)
#   hit/VBD
#   him/PRP
#   hard/VB
#   on/IN
#   the/DT
#   head/NN
#   and/CC
#   rebounded/VBD
#   to/TO
#   wicket-keeper/JJ
#   (PERSON Khaled/NNP Mashud/NNP)
#   ./.
#   A/DT
#   cricket/NN
#   umpire/NN
#   ,/,
#   (PERSON Alcwyn/NNP Jenkins/NNP)
#   ,/,
#   died/VBD
#   in/IN
#   2009/CD
#   in/IN
#   (GPE Swansea/NNP)
#   ,/,
#   (PERSON Wales/NNP)
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   the/DT
#   head/NN
#   by/IN
#   a/DT
#   ball/NN
#   thrown/VBN
#   by/IN
#   a/DT
#   fielder/NN
#   ./.
#   On/IN
#   27/CD
#   October/NNP
#   2013/CD
#   ,/,
#   (GPE South/NNP African/NNP)
#   cricketer/NN
#   (PERSON Darryn/NNP Randall/NNP)
#   died/VBD
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   the/DT
#   head/NN
#   by/IN
#   the/DT
#   ball/NN
#   while/IN
#   batting/VBG
#   ./.
#   He/PRP
#   collapsed/VBD
#   immediately/RB
#   and/CC
#   was/VBD
#   rushed/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION Alice/NNP Hospital/NNP)
#   ,/,
#   but/CC
#   the/DT
#   medical/JJ
#   staff/NN
#   could/MD
#   not/RB
#   revive/VB
#   him/PRP
#   ./.
#   In/IN
#   November/NNP
#   2014/CD
#   ,/,
#   (GPE Australia/NNP)
#   and/CC
#   (GPE South/NNP Australia/NNP)
#   batsman/NN
#   (PERSON Phillip/NNP Hughes/NNP)
#   died/VBD
#   at/IN
#   the/DT
#   age/NN
#   of/IN
#   25/CD
#   at/IN
#   a/DT
#   (GPE Sydney/NNP)
#   hospital/NN
#   after/IN
#   he/PRP
#   was/VBD
#   hit/VBN
#   on/IN
#   the/DT
#   side/NN
#   of/IN
#   the/DT
#   neck/NN
#   by/IN
#   a/DT
#   bouncer/NN
#   bowled/VBN
#   by/IN
#   (PERSON Sean/NNP Abbott/NNP)
#   during/IN
#   a/DT
#   (ORGANIZATION Sheffield/NNP Shield/NNP)
#   game/NN
#   ./.
#   The/DT
#   same/JJ
#   week/NN
#   ,/,
#   (PERSON Hillel/NNP Oscar/NNP)
#   ,/,
#   an/DT
#   umpire/NN
#   and/CC
#   former/JJ
#   captain/NN
#   of/IN
#   (GPE Israel/NNP)
#   's/POS
#   national/JJ
#   cricket/NN
#   team/NN
#   ,/,
#   died/VBD
#   after/IN
#   being/VBG
#   hit/VBN
#   in/IN
#   the/DT
#   neck/NN
#   by/IN
#   a/DT
#   ball/NN
#   ./.
#   On/IN
#   14/CD
#   August/NNP
#   2017/CD
#   ,/,
#   (PERSON Zubair/NNP Ahmed/NNP)
#   died/VBD
#   after/IN
#   being/VBG
#   hit/VBN
#   on/IN
#   the/DT
#   head/NN
#   while/IN
#   batting/VBG
#   in/IN
#   a/DT
#   club/NN
#   match/NN
#   played/VBN
#   in/IN
#   the/DT
#   (ORGANIZATION Mardan/NNP District/NNP)
#   ,/,
#   (PERSON Khyber/NNP Pakhtunkhwa/NNP)
#   ,/,
#   (GPE Pakistan/NNP)
#   ./.
#   Sometimes/RB
#   alternatives/NNS
#   to/TO
#   a/DT
#   real/JJ
#   cricket/NN
#   ball/NN
#   may/MD
#   be/VB
#   preferred/VBN
#   for/IN
#   reasons/NNS
#   of/IN
#   safety/NN
#   ,/,
#   availability/NN
#   and/CC
#   cost/NN
#   ./.
#   (PERSON Examples/NNP)
#   include/VBP
#   a/DT
#   tennis/NN
#   ball/NN
#   and/CC
#   a/DT
#   plastic/JJ
#   version/NN
#   of/IN
#   the/DT
#   cricket/NN
#   ball/NN
#   ./.
#   Many/JJ
#   casual/JJ
#   players/NNS
#   use/VBP
#   a/DT
#   tennis/NN
#   ball/NN
#   wrapped/VBD
#   in/IN
#   layers/NNS
#   of/IN
#   some/DT
#   type/NN
#   of/IN
#   adhesive/JJ
#   tape/NN
#   (/(
#   often/RB
#   electrical/JJ
#   tape/NN
#   )/)
#   ,/,
#   which/WDT
#   makes/VBZ
#   the/DT
#   relatively/RB
#   soft/JJ
#   tennis/NN
#   ball/NN
#   harder/NN
#   and/CC
#   smoother/NN
#   ./.
#   This/DT
#   is/VBZ
#   commonly/RB
#   referred/VBN
#   to/TO
#   as/IN
#   a/DT
#   tape/NN
#   ball/NN
#   ./.
#   A/DT
#   common/JJ
#   variant/NN
#   is/VBZ
#   to/TO
#   tape/VB
#   only/RB
#   half/PDT
#   the/DT
#   tennis/NN
#   ball/NN
#   ,/,
#   to/TO
#   provide/VB
#   two/CD
#   different/JJ
#   sides/NNS
#   and/CC
#   make/VB
#   it/PRP
#   easy/JJ
#   to/TO
#   bowl/VB
#   with/IN
#   prodigious/JJ
#   amounts/NNS
#   of/IN
#   swing/NN
#   ./.
#   Younger/JJR
#   players/NNS
#   often/RB
#   use/VBP
#   either/DT
#   tennis/NN
#   balls/VBZ
#   or/CC
#   an/DT
#   air-filled/JJ
#   plastic/NN
#   'windball/POS
#   '/''
#   for/IN
#   safety/NN
#   reasons/NNS
#   before/IN
#   using/VBG
#   the/DT
#   'hard/NNP
#   '/POS
#   cricket/NN
#   ball/NN
#   after/IN
#   a/DT
#   certain/JJ
#   age/NN
#   :/:
#   windball/NN
#   cricket/NN
#   is/VBZ
#   also/RB
#   a/DT
#   popular/JJ
#   sport/NN
#   in/IN
#   its/PRP$
#   own/JJ
#   right/NN
#   ./.
#   They/PRP
#   might/MD
#   also/RB
#   use/VB
#   an/DT
#   'IncrediBall/NN
#   '/''
#   or/CC
#   an/DT
#   'Aeroball/NN
#   '/POS
#   whilst/NN
#   making/VBG
#   the/DT
#   step/NN
#   between/IN
#   windballs/NNS
#   and/CC
#   'hard/NNP
#   '/POS
#   cricket/NN
#   balls/NNS
#   ./.
#   These/DT
#   balls/NNS
#   are/VBP
#   designed/VBN
#   to/TO
#   mimic/VB
#   the/DT
#   feel/NN
#   ,/,
#   speed/NN
#   and/CC
#   bounce/NN
#   of/IN
#   a/DT
#   regular/JJ
#   hard/JJ
#   ball/NN
#   ,/,
#   but/CC
#   soften/VBD
#   when/WRB
#   coming/VBG
#   in/IN
#   contact/NN
#   with/IN
#   objects/NNS
#   at/IN
#   high/JJ
#   speed/NN
#   ,/,
#   reducing/VBG
#   the/DT
#   risk/NN
#   of/IN
#   injury/NN
#   ./.)

# %%
for sent in nltk.sent_tokenize(article_text):
   for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
      if hasattr(chunk, 'label'):
         print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# GPE Cricket
# PERSON Test
# GPE British
# ORGANIZATION Standard
# FACILITY White
# ORGANIZATION Kookaburra
# ORGANIZATION Twenty20
# LOCATION West
# GPE England
# PERSON Dukes
# GPE India
# GPE Cricket
# GPE Test
# GPE White
# ORGANIZATION ODI
# GPE Pink
# ORGANIZATION England Women
# GPE Australia
# ORGANIZATION Wormsley
# GPE Test
# GPE England
# GPE Amateur
# PERSON Dukes
# ORGANIZATION SG
# GPE India
# ORGANIZATION SG
# GPE England
# GPE Ireland
# LOCATION West
# GPE Dukes
# PERSON Kookaburra
# ORGANIZATION Kookaburra
# FACILITY White
# ORGANIZATION Dukes
# ORGANIZATION Kookaburra
# GPE Domestic
# GPE Pakistan
# GPE Grays
# GPE Cricket
# GPE Cricket
# GPE Test
# PERSON Simon Doull
# PERSON Cricket
# ORGANIZATION ICC
# GPE British
# LOCATION West Indian
# PERSON Ian Bishop
# GPE Test
# GPE Limited
# ORGANIZATION Laws
# GPE Cricket
# GPE Cricket
# GPE Cricket
# GPE Frederick
# GPE Prince
# GPE Wales
# GPE Glamorgan
# PERSON Roger Davis
# GPE Indian
# PERSON Nariman
# PERSON Contractor
# LOCATION West
# GPE Indian
# PERSON Raman Lamba
# GPE Dhaka
# PERSON Lamba
# PERSON Mehrab Hossain
# PERSON Khaled Mashud
# PERSON Alcwyn Jenkins
# GPE Swansea
# PERSON Wales
# GPE South African
# PERSON Darryn Randall
# ORGANIZATION Alice Hospital
# GPE Australia
# GPE South Australia
# PERSON Phillip Hughes
# GPE Sydney
# PERSON Sean Abbott
# ORGANIZATION Sheffield Shield
# PERSON Hillel Oscar
# GPE Israel
# PERSON Zubair Ahmed
# ORGANIZATION Mardan District
# PERSON Khyber Pakhtunkhwa
# GPE Pakistan

# %%
sentence_list = nltk.sent_tokenize(article_text)  #fommatted data doesn;t contain punctuation so article_text used

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Gautam
# [nltk_data]     Nair\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')     #all stopwords stored here

# %%
word_frequencies = {}    #calculating freq of words(excluding stopwords)

# %%
for word in nltk.word_tokenize(formatted_article_text):  
    if word not in stopwords:
        if word not in word_frequencies.keys():    #encountered for the first time
            word_frequencies[word] = 1     
        else:                                      #incrementing count
            word_frequencies[word] += 1

# %%
print(word_frequencies)
# Out:
# {'A': 11, 'cricket': 47, 'ball': 84, 'hard': 6, 'solid': 1, 'used': 27, 'play': 3, 'consists': 1, 'cork': 2, 'core': 2, 'wound': 2, 'string': 3, 'leather': 6, 'cover': 1, 'stitched': 3, 'manufacture': 1, 'regulated': 1, 'law': 1, 'first': 8, 'class': 6, 'level': 2, 'The': 16, 'trajectory': 1, 'bowled': 4, 'movement': 3, 'air': 7, 'ground': 3, 'influenced': 1, 'action': 1, 'bowler': 5, 'condition': 6, 'pitch': 5, 'working': 1, 'obtain': 1, 'optimum': 1, 'key': 2, 'role': 1, 'fielding': 4, 'side': 4, 'principal': 1, 'method': 1, 'batsman': 4, 'scores': 1, 'runs': 1, 'hitting': 2, 'bat': 1, 'position': 1, 'would': 1, 'safe': 1, 'take': 1, 'run': 1, 'directing': 1, 'boundary': 1, 'Cricket': 10, 'balls': 41, 'harder': 3, 'heavier': 1, 'baseballs': 1, 'In': 9, 'day': 9, 'Test': 7, 'professional': 4, 'domestic': 2, 'games': 1, 'spread': 1, 'multitude': 1, 'days': 1, 'almost': 1, 'entirety': 1, 'amateur': 1, 'traditional': 1, 'red': 12, 'normally': 1, 'many': 1, 'one': 13, 'matches': 12, 'white': 13, 'instead': 1, 'order': 2, 'remain': 1, 'visible': 2, 'floodlights': 2, 'since': 2, 'pink': 7, 'introduced': 2, 'contrast': 1, 'players': 6, 'clothing': 1, 'improved': 2, 'night': 9, 'visibility': 4, 'Training': 1, 'also': 8, 'common': 2, 'tennis': 6, 'similar': 4, 'sized': 1, 'training': 1, 'informal': 1, 'During': 1, 'quality': 4, 'changes': 2, 'point': 2, 'longer': 1, 'usable': 1, 'decline': 1, 'properties': 1, 'alter': 1, 'thus': 1, 'influence': 1, 'match': 12, 'Altering': 1, 'state': 1, 'outside': 1, 'permitted': 1, 'manners': 1, 'designated': 1, 'rules': 3, 'prohibited': 1, 'called': 2, 'tampering': 2, 'resulted': 1, 'numerous': 1, 'controversies': 1, 'Injuries': 1, 'fatalities': 1, 'caused': 1, 'hazards': 1, 'posed': 1, 'motivator': 1, 'introduction': 1, 'protective': 2, 'equipment': 2, 'British': 2, 'Standard': 1, 'BS': 1, 'specifies': 1, 'construction': 1, 'details': 1, 'dimensions': 1, 'performance': 1, 'made': 2, 'layered': 1, 'tightly': 1, 'covered': 1, 'case': 2, 'slightly': 3, 'raised': 1, 'sewn': 1, 'seam': 6, 'top': 1, 'suitable': 1, 'highest': 2, 'levels': 2, 'competition': 2, 'covering': 2, 'constructed': 1, 'four': 1, 'pieces': 2, 'shaped': 1, 'peel': 1, 'quartered': 1, 'orange': 2, 'hemisphere': 1, 'rotated': 1, 'degrees': 1, 'respect': 1, 'equator': 1, 'form': 1, 'prominent': 1, 'six': 1, 'rows': 1, 'stitches': 1, 'remaining': 1, 'two': 6, 'joins': 1, 'internally': 1, 'forming': 1, 'quarter': 1, 'Lower': 1, 'piece': 1, 'popular': 2, 'practice': 1, 'lower': 2, 'due': 4, 'cost': 2, 'nature': 1, 'varies': 2, 'manufacturer': 4, 'White': 3, 'Kookaburra': 6, 'Twenty': 1, 'international': 5, 'Kookaburras': 1, 'test': 3, 'played': 7, 'ten': 1, 'playing': 2, 'nations': 1, 'except': 3, 'West': 4, 'Indies': 3, 'England': 4, 'use': 13, 'Dukes': 6, 'India': 2, 'SG': 3, 'traditionally': 2, 'First': 1, 'proposals': 1, 'introduce': 1, 'colours': 2, 'date': 1, 'back': 1, 'least': 2, 'early': 1, 'began': 1, 'even': 2, 'found': 1, 'behave': 2, 'differently': 2, 'notably': 1, 'swing': 8, 'lot': 2, 'half': 2, 'innings': 6, 'deteriorate': 1, 'quickly': 2, 'Manufacturers': 1, 'claim': 1, 'manufactured': 1, 'using': 4, 'methods': 1, 'materials': 1, 'dyeing': 1, 'Another': 1, 'problem': 1, 'associated': 1, 'One': 1, 'Day': 1, 'Internationals': 2, 'become': 2, 'dirty': 2, 'dull': 1, 'colour': 2, 'makes': 2, 'difficult': 3, 'batsmen': 2, 'sight': 1, 'overs': 7, 'Since': 2, 'October': 5, 'managed': 2, 'new': 11, 'different': 6, 'bowling': 3, 'end': 3, 'strategy': 1, 'World': 4, 'Cups': 2, 'Between': 1, 'issue': 1, 'start': 3, 'swapping': 1, 'th': 1, 'reconditioned': 1, 'neither': 1, 'see': 3, 'Before': 1, 'ODI': 1, 'umpires': 2, 'discretion': 1, 'change': 1, 'Pink': 1, 'developed': 1, 'enable': 1, 'Tests': 2, 'unsuited': 2, 'tests': 1, 'poor': 1, 'deteriorates': 1, 'rapidly': 1, 'eighty': 1, 'specified': 2, 'designed': 2, 'provide': 2, 'satisfactory': 1, 'compromise': 1, 'issues': 1, 'It': 3, 'still': 2, 'considered': 1, 'heavily': 1, 'dyed': 1,  ...

# %%
maximum_frequncy = max(word_frequencies.values())

# %%
#Calculating weighted freq of all words
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

# %%
sentence_scores = {}    #calculating freq of sentences

# %%
for sent in sentence_list:  
    for word in nltk.word_tokenize(sent.lower()):   #convert to lowercase
        if word in word_frequencies.keys():        
            if len(sent.split(' ')) < 30:      #for smaller sentences < 30
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
import heapq    #to retrieve highest scores

# %%
summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

# %%
summary = ' '.join(summary_sentences)
print(summary)
# Out:
# If the ball is damaged, lost, or illegally modified, it will be replaced by a used ball in similar condition to the replaced ball.  A cricket ball is a hard, solid ball used to play cricket. In day Test cricket, professional domestic games that spread over a multitude of days, and almost the entirety of amateur cricket, the traditional red cricket ball is normally used. A new cricket ball is harder than a worn one, and is preferred by fast bowlers because of the speed and bounce of the ball off the pitch. Training balls of white, red and pink are also common, and tennis balls and other similar-sized balls can be used for training or informal cricket matches. White Dukes balls were used at the 1999 Cricket World Cup, but the ball behaved more erratically than the Kookaburra and white Dukes have not been used since. Amateur cricketers often have to use old balls, or cheap substitutes, in which case the changes in the condition of the ball may be different from professional cricket.
